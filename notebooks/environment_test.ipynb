# %% [markdown]
# # Environment test
#
# ## 1. Verify data science/ML libraries
#
# Check that TensorFlow is importable and is the correct version (2.16)

# %%
import tensorflow as tf
print('TensorFlow version:', tf.__version__)
# Out:
# TensorFlow version: 2.16.1

# %% [markdown]
# Check that GPU(s) are correctly detected and available

# %%
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %% [markdown]
# Check other data science libraries:

# %%
import matplotlib as mpl
import numpy as np
import pandas as pd
import scipy as sp
import sklearn as sk

print('Matplotlib version:', mpl.__version__)
print('NumPy version:', np.__version__)
print('Pandas version:', pd.__version__)
print('Scikit-learn version:', sk.__version__)
print('SciPy version:', sp.__version__)
# Out:
# Matplotlib version: 3.10.8
# NumPy version: 1.24.4
# Pandas version: 2.2.1
# Scikit-learn version: 1.4.2
# SciPy version: 1.13.1

# %% [markdown]
# ## 2. GPU load test

# %%
# GPU load test - Matrix multiplication with memory scaling
from functions.gpu_load_test import run_gpu_load_test

target_memory_percent = 75.0
test_duration_seconds = 10 * 60

gpu_results = run_gpu_load_test(target_memory_percent, test_duration_seconds)
# Out:
# Memory growth enabled for 2 GPU(s)
# ============================================================
# Testing GPU 0: /physical_device:GPU:0
# ============================================================
# Total GPU memory: 16384 MB
# Initial memory used: 8 MB (0.0%)
# Target: 75.0% memory usage
#
# Trying matrix size: 1000x1000... Memory: 306 MB (1.9%)
# Trying matrix size: 2000x2000... Memory: 402 MB (2.5%)
# Trying matrix size: 3000x3000... Memory: 786 MB (4.8%)
# Trying matrix size: 4000x4000... Memory: 786 MB (4.8%)
# Trying matrix size: 5000x5000... Memory: 1298 MB (7.9%)
# Trying matrix size: 6000x6000... Memory: 2322 MB (14.2%)
# Trying matrix size: 7000x7000... Memory: 2322 MB (14.2%)
# Trying matrix size: 8000x8000... Memory: 2322 MB (14.2%)
# Trying matrix size: 9000x9000... Memory: 4370 MB (26.7%)
# Trying matrix size: 10000x10000... Memory: 4370 MB (26.7%)
# Trying matrix size: 11000x11000... Memory: 4370 MB (26.7%)
# Trying matrix size: 12000x12000... Memory: 8466 MB (51.7%)
# Trying matrix size: 13000x13000... Memory: 8466 MB (51.7%)
# Trying matrix size: 14000x14000... Memory: 8466 MB (51.7%)
# Trying matrix size: 15000x15000... Memory: 8466 MB (51.7%)
# Trying matrix size: 16000x16000... Memory: 8466 MB (51.7%)
# Trying matrix size: 17000x17000... Memory: 15568 MB (95.0%)
#
# Reached 95.0% memory usage with 17000x17000 matrices
#
# Running stress test for 10 minutes at 17000x17000...
# Initial temperature: 30°C, Initial power: 37.6W
#   32s elapsed, 568s remaining - Temp: 36°C, Peak power: 39.5W, Iterations: 13
#   64s elapsed, 536s remaining - Temp: 40°C, Peak power: 40.8W, Iterations: 26
#   96s elapsed, 504s remaining - Temp: 42°C, Peak power: 42.0W, Iterations: 39
#   129s elapsed, 471s remaining - Temp: 44°C, Peak power: 42.7W, Iterations: 52
#   161s elapsed, 439s remaining - Temp: 45°C, Peak power: 43.0W, Iterations: 65
#   193s elapsed, 407s remaining - Temp: 46°C, Peak power: 43.5W, Iterations: 78
#   226s elapsed, 374s remaining - Temp: 46°C, Peak power: 43.7W, Iterations: 91
#   256s elapsed, 344s remaining - Temp: 47°C, Peak power: 43.7W, Iterations: 103
#   286s elapsed, 314s remaining - Temp: 47°C, Peak power: 43.9W, Iterations: 115
#   318s elapsed, 282s remaining - Temp: 47°C, Peak power: 44.2W, Iterations: 128
#   350s elapsed, 250s remaining - Temp: 48°C, Peak power: 44.2W, Iterations: 141
#   383s elapsed, 217s remaining - Temp: 48°C, Peak power: 44.4W, Iterations: 154
#   415s elapsed, 185s remaining - Temp: 48°C, Peak power: 44.5W, Iterations: 167
#   447s elapsed, 153s remaining - Temp: 48°C, Peak power: 44.5W, Iterations: 180
#   479s elapsed, 121s remaining - Temp: 48°C, Peak power: 44.7W, Iterations: 193
#   512s elapsed, 88s remaining - Temp: 49°C, Peak power: 44.7W, Iterations: 206
#   544s elapsed, 56s remaining - Temp: 48°C, Peak power: 44.7W, Iterations: 219
#   574s elapsed, 26s remaining - Temp: 48°C, Peak power: 44.7W, Iterations: 231
#
# GPU 0 stress test completed!
#   - Final matrix size: 17000x17000
#   - Peak memory usage: 15568 MB (95.0%)
#   - Total iterations: 242
#   - Total time: 601.6 seconds (10.0 minutes)
#   - Avg time per operation: 2.4860 seconds
#   - Temperature: 30°C → 48°C (Δ+18°C)
#   - Peak power draw: 44.7W
#
# ============================================================
# Testing GPU 1: /physical_device:GPU:1
# ============================================================
# Total GPU memory: 8192 MB
# Initial memory used: 999 MB (12.2%)
# Target: 75.0% memory usage
#
# Trying matrix size: 1000x1000... Memory: 1041 MB (12.7%)
# Trying matrix size: 2000x2000... Memory: 1137 MB (13.9%)
# Trying matrix size: 3000x3000... Memory: 1521 MB (18.6%)
# Trying matrix size: 4000x4000... Memory: 1521 MB (18.6%)
# Trying matrix size: 5000x5000... Memory: 2033 MB (24.8%)
# Trying matrix size: 6000x6000... Memory: 3057 MB (37.3%)
# Trying matrix size: 7000x7000... Memory: 3057 MB (37.3%)
# Trying matrix size: 8000x8000... Memory: 3057 MB (37.3%)
# Trying matrix size: 9000x9000... Memory: 5105 MB (62.3%)
# Trying matrix size: 10000x10000... Memory: 5105 MB (62.3%)
# Trying matrix size: 11000x11000... Memory: 5105 MB (62.3%)
# Trying matrix size: 12000x12000... Memory: 7389 MB (90.2%)
#
# Reached 90.2% memory usage with 12000x12000 matrices
#
# Running stress test for 10 minutes at 12000x12000...
# Initial temperature: 58°C, Initial power: 45.5W
#   31s elapsed, 569s remaining - Temp: 60°C, Peak power: 48.6W, Iterations: 22
#   62s elapsed, 538s remaining - Temp: 61°C, Peak power: 50.5W, Iterations: 44
#   93s elapsed, 507s remaining - Temp: 61°C, Peak power: 50.5W, Iterations: 66
#   125s elapsed, 475s remaining - Temp: 61°C, Peak power: 50.5W, Iterations: 88
#   156s elapsed, 444s remaining - Temp: 60°C, Peak power: 50.5W, Iterations: 110
#   187s elapsed, 413s remaining - Temp: 61°C, Peak power: 50.5W, Iterations: 132
#   218s elapsed, 382s remaining - Temp: 61°C, Peak power: 51.5W, Iterations: 154
#   248s elapsed, 352s remaining - Temp: 61°C, Peak power: 51.6W, Iterations: 175
#   279s elapsed, 321s remaining - Temp: 61°C, Peak power: 51.6W, Iterations: 197
#   310s elapsed, 290s remaining - Temp: 61°C, Peak power: 51.6W, Iterations: 219
#   341s elapsed, 259s remaining - Temp: 60°C, Peak power: 51.6W, Iterations: 241
#   372s elapsed, 228s remaining - Temp: 60°C, Peak power: 51.6W, Iterations: 263
#   403s elapsed, 197s remaining - Temp: 60°C, Peak power: 52.0W, Iterations: 285
#   435s elapsed, 165s remaining - Temp: 60°C, Peak power: 52.0W, Iterations: 307
#   466s elapsed, 134s remaining - Temp: 60°C, Peak power: 52.0W, Iterations: 329
#   497s elapsed, 103s remaining - Temp: 60°C, Peak power: 52.0W, Iterations: 351
#   528s elapsed, 72s remaining - Temp: 60°C, Peak power: 52.0W, Iterations: 373
#   558s elapsed, 42s remaining - Temp: 60°C, Peak power: 52.0W, Iterations: 394
#   589s elapsed, 11s remaining - Temp: 60°C, Peak power: 52.0W, Iterations: 416
#
# GPU 1 stress test completed!
#   - Final matrix size: 12000x12000
#   - Peak memory usage: 7376 MB (90.0%)
#   - Total iterations: 424
#   - Total time: 600.7 seconds (10.0 minutes)
#   - Avg time per operation: 1.4167 seconds
#   - Temperature: 58°C → 60°C (Δ+2°C)
#   - Peak power draw: 52.0W
#
# ============================================================
# All 2 GPU(s) stress tested successfully!
# ============================================================

# %%
# Plot temperature over time for each GPU
from functions.gpu_load_test import plot_temperature_results

plot_temperature_results(gpu_results)
