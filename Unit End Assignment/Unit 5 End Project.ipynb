# %% [markdown]
# # Career Simulation Projects
#
# ## Course 5
#
# ---
#
# ## Streamlining the Customer Grievance Process

# %%
# install missing python libraries
# %pip install nltk scikit-learn numpy pandas matplotlib tensorflow keras --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Imports

# %%
import os
import nltk
import keras
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.utils import class_weight
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from keras import layers, Model
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import AdamW, Adam
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping
from keras.losses import CategoricalFocalCrossentropy

# Set KERAS_BACKEND to TensorFlow
os.environ['KERAS_BACKEND'] = 'tensorflow'

# Download necessary NLTK resources
nltk.download('stopwords')
nltk.download('vader_lexicon')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\simsk\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\simsk\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\simsk\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# ## Load complaints dataset into a pandas DataFrame

# %%
complaints_df = pd.read_csv('../data/complaints_banking_2023.txt')

# Look for null values in the dataset
print(complaints_df.isnull().sum())

# While not practical in all cases, we cannot run sentiment analysis on rows with a missing customer complaint, so those rows will be dropped.
no_null_complaints_df = complaints_df.dropna(subset=['Complaint Description'])
print(no_null_complaints_df.isnull().sum())
# Out:
# Complaint ID             1329
# Date Received            1334
# Banking Product          1325
# Department               1335
# Issue ID                 1331
# Complaint Description    1330
# State                    1359
# ZIP                      1348
# Bank Response            1329
# dtype: int64
# Complaint ID             1074
# Date Received            1087
# Banking Product          1078
# Department               1097
# Issue ID                 1092
# Complaint Description       0
# State                    1093
# ZIP                      1097
# Bank Response            1089
# dtype: int64

# %% [markdown]
# #### Load the dept and convert it into a list of dictionaries to help fill out data in the main complaints dataset

# %%
dept_df = pd.read_csv('../data/Department_of_Product.txt')
dept_dict = dict(zip(dept_df['Product'], dept_df['Department']))
print(dept_dict)

# Fill out the missing values in the Department column of the complaints dataset by seeing if a the row has a Product value that matches a key in the dept_dict. 
# If a match is found, the corresponding Department value from the dept_dict will be used to fill the missing value. Then print the row the update was made to
dept_filled_complaints_df = no_null_complaints_df.copy()
for index, row in no_null_complaints_df.iterrows():
    if pd.isnull(row['Department']):
        product = row['Banking Product']
        if product in dept_dict:
            dept_filled_complaints_df.at[index, 'Department'] = dept_dict[product]
            #print(dept_filled_complaints_df.loc[index])

print(dept_filled_complaints_df.isnull().sum())
# Since a department serves different banking products the reverse cannot be applied
# Out:
# {'Checking or savings account': 'CASA', 'Credit reporting, credit repair services, or other personal consumer reports': 'Credit Reports', 'Credit card or prepaid card': 'Credit Cards', 'Debt collection': 'Loans', 'Money transfer, virtual currency, or money service': 'Remittance', 'Mortgage': 'Mortgage', 'Vehicle loan or lease': 'Loans', 'Payday loan, title loan, or personal loan': 'Loans', 'Student loan': 'Loans', 'Credit Card': 'Credit Cards', 'Credit Reporting': 'Credit Reports', 'Payday loan': 'Loans', 'Bank Account or Service': 'Others', 'Money transfers': 'Remittance', 'Prepaid Card': 'Credit Cards', 'Consumer Loan': 'Loans', 'Other financial service': 'Others'}
# Complaint ID             1074
# Date Received            1087
# Banking Product          1078
# Department                384
# Issue ID                 1092
# Complaint Description       0
# State                    1093
# ZIP                      1097
# Bank Response            1089
# dtype: int64

# %% [markdown]
# From the assignment, this function should:
# 1. Convert text to lowercase
# 2. Handle numbers
# 3. Handle stop words
# 4. Handle punctuation
# 5. Apply lemmatization

# %%
test_text = """I Contacted Seller by email XX/XX/XXXX, XXXX pm, received email from XXXX, for XXXX # XXXX, confirming order.
            Ant chged to my XXXX was {$32.00} USD I clicked on View your Order and was given the Shipper and Tracking number : Shipper : XXXX ; Tracking number : XXXX.
            When I clicked on the tracking number, it had not been sent yet.
            I looked up this XXXX  through XXXX, and found XXXX, XXXX XXXX XXXX XXXX, XXXX XXXX, CA XXXX.
            ( This address, according to USPS records and XXXX, is just a house/residence, in XXXX XXXX XXXX California ) ).
            This address is a rental propertyin XXXX XXXX???"""

def preprocessing_pipeline(text):
    # Convert text to lowercase
    text = text.lower()
    
    # Handle stop words:
    stop_words = set(stopwords.words('english'))
    text = ' '.join(word for word in text.split() if word not in stop_words)
    
    # Remove punctuation and special characters
    text = ''.join(char for char in text if char.isalnum() or char.isspace())
    
    # Handle numbers: convert all numbers to a special token (e.g., <NUM>)
    text = ''.join('<NUM>' if char.isdigit() else char for char in text)
    
    # Apply lemmatization
    lemmatizer = WordNetLemmatizer()
    text = ' '.join(lemmatizer.lemmatize(word) for word in text.split())
    
    # Normalize whitespace and condense multiple spaces into one space
    text = ' '.join(text.split())
    
    return text

# Print out our test text after processing to see the changes
print(preprocessing_pipeline(test_text))
# Out:
# contacted seller email xxxxxxxx xxxx pm received email xxxx xxxx xxxx confirming order ant chged xxxx <NUM><NUM><NUM><NUM> usd clicked view order given shipper tracking number shipper xxxx tracking number xxxx clicked tracking number sent yet looked xxxx xxxx found xxxx xxxx xxxx xxxx xxxx xxxx xxxx ca xxxx address according usps record xxxx houseresidence xxxx xxxx xxxx california address rental propertyin xxxx xxxx

# %%
# Preprocess the complaint descriptions in the dataset using the preprocessing_pipeline function and put into a new df overwriting the original complaint description column.
processed_complaints_df = dept_filled_complaints_df.copy()
processed_complaints_df['Complaint Description'] = processed_complaints_df['Complaint Description'].apply(preprocessing_pipeline)
print(processed_complaints_df['Complaint Description'].head())

# Save the preprocessed complaints dataset to a new CSV file
processed_complaints_df.to_csv('../data/processed_complaints_banking_2023.csv', index=False)
# Out:
# 0    xxxxxx<NUM><NUM> opened safe balance account o...
# 1    item bank abc credit report belong must remove...
# 2    xxxxxx<NUM><NUM> found account frozen apparent...
# 5    so last time phone b prepaid regarding edd acc...
# 6    got <NUM> hard inquiry dont recognize xxxx xxx...
# Name: Complaint Description, dtype: str

# %%
# Load the preprocessed complaints dataset
processed_complaints_df = pd.read_csv('processed_complaints_banking_2023.csv')

# %%
# Vectorize the complaint descriptions using TF-IDF
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(processed_complaints_df['Complaint Description'])
print(processed_complaints_df.shape)
print(tfidf_matrix.shape)
# Out:
# (5681, 9)
# (5681, 14795)

# %%
# Separate the target variable (Department) from the features (Complaint Descriptions)
X = tfidf_matrix
# Text labels need to be converted to numerical values for the model
y = to_categorical(processed_complaints_df['Department'].factorize()[0])
# Remove any rows from X and y by index using the original dataframe in which the Department value is null
# These can be saved for validation on later
null_dept_indices = processed_complaints_df[processed_complaints_df['Department'].isnull()].index
X_base = X[~processed_complaints_df.index.isin(null_dept_indices)]
y_base = y[~processed_complaints_df.index.isin(null_dept_indices)]
X_val = X[processed_complaints_df.index.isin(null_dept_indices)]
y_val = y[processed_complaints_df.index.isin(null_dept_indices)]
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_base, y_base, test_size=0.1, random_state=691)

# %%
# Define the neural network model
loss_fn = CategoricalFocalCrossentropy(alpha=0.2, gamma=2.0)
def create_model(input_dim, output_dim):
    input_layer = layers.Input(shape=(input_dim,))
    hidden_layer_1 = layers.Dense(64, activation='relu')(input_layer)
    hidden_layer_1 = layers.Dropout(0.5)(hidden_layer_1)
    hidden_layer_2 = layers.Dense(128, activation='relu')(hidden_layer_1)
    hidden_layer_2 = layers.Dropout(0.5)(hidden_layer_2)
    hidden_layer_3 = layers.Dense(256, activation='relu')(hidden_layer_2)
    hidden_layer_3 = layers.Dropout(0.5)(hidden_layer_3)
    hidden_layer_4 = layers.Dense(256, activation='relu')(hidden_layer_3)
    hidden_layer_4 = layers.Dropout(0.5)(hidden_layer_4)
    hidden_layer_5 = layers.Dense(128, activation='relu')(hidden_layer_4)
    hidden_layer_5 = layers.Dropout(0.5)(hidden_layer_5)
    # softmax, in general, is the better output activation func for multi-class classification problems
    output_layer = layers.Dense(output_dim, activation='softmax')(hidden_layer_5)
    model = Model(inputs=input_layer, outputs=output_layer)
    model.compile(optimizer=AdamW(learning_rate=1e-5), loss=loss_fn, metrics=['accuracy', 'Precision', 'Recall'])
    return model

# %%
# Make a class weights dictionary for the imbalanced dataset to help the model learn better
class_weights = class_weight.compute_class_weight(class_weight='balanced', classes=np.unique(processed_complaints_df['Department'].factorize()[0]), y=processed_complaints_df['Department'].factorize()[0])
class_weights_dict = dict(enumerate(class_weights))
print(class_weights_dict)
class_weights_dict[5] = class_weights_dict[5] + 1
class_weights_dict[7] = class_weights_dict[7] + 1
print(class_weights_dict)
# Out:
# {0: np.float64(1.8492838541666667), 1: np.float64(0.5530568535825545), 2: np.float64(0.888767209011264), 3: np.float64(0.5977483164983165), 4: np.float64(0.8115714285714286), 5: np.float64(2.165015243902439), 6: np.float64(1.063061377245509), 7: np.float64(4.5814516129032254)}
# {0: np.float64(1.8492838541666667), 1: np.float64(0.5530568535825545), 2: np.float64(0.888767209011264), 3: np.float64(0.5977483164983165), 4: np.float64(0.8115714285714286), 5: np.float64(3.165015243902439), 6: np.float64(1.063061377245509), 7: np.float64(5.5814516129032254)}

# %%
# Create a keras model for classification using functional API
model = create_model(input_dim=X_train.shape[1], output_dim=y_train.shape[1])
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 14795)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 64)             │       946,944 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 256)            │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,087,879 (4.15 MB)
#  Trainable params: 1,087,879 (4.15 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model with early stopping callback to prevent overfitting
early_stopping = keras.callbacks.EarlyStopping(monitor='val_Recall', patience=50, restore_best_weights=True, verbose=0, start_from_epoch=30)
# model.fit(X_train, y_train, epochs=1000, batch_size=64, validation_data=(X_test, y_test), callbacks=[early_stopping], class_weight=class_weights_dict)
#model.fit(X_train, y_train, epochs=1000, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping])
model.fit(X_train, y_train, epochs=1000, batch_size=32, validation_data=(X_test, y_test))
# Evaluate the model on the test set
loss, accuracy, precision, recall = model.evaluate(X_test, y_test)
print(f'Test Loss: {loss:.4f}, Test Accuracy: {accuracy:.4f}', f'Precision: {precision:.4f}', f'Recall: {recall:.4f}')
# Out:
# Epoch 1/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9376 - Recall: 0.8949 - accuracy: 0.9218 - loss: 0.0152 - val_Precision: 0.6809 - val_Recall: 0.6321 - val_accuracy: 0.6472 - val_loss: 0.2663
# Epoch 2/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - Precision: 0.9349 - Recall: 0.8978 - accuracy: 0.9226 - loss: 0.0160 - val_Precision: 0.6796 - val_Recall: 0.6283 - val_accuracy: 0.6453 - val_loss: 0.2667
# Epoch 3/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - Precision: 0.9359 - Recall: 0.8947 - accuracy: 0.9203 - loss: 0.0151 - val_Precision: 0.6761 - val_Recall: 0.6302 - val_accuracy: 0.6434 - val_loss: 0.2660
# Epoch 4/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - Precision: 0.9416 - Recall: 0.9025 - accuracy: 0.9291 - loss: 0.0147 - val_Precision: 0.6748 - val_Recall: 0.6264 - val_accuracy: 0.6434 - val_loss: 0.2676
# Epoch 5/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - Precision: 0.9373 - Recall: 0.8930 - accuracy: 0.9218 - loss: 0.0158 - val_Precision: 0.6762 - val_Recall: 0.6264 - val_accuracy: 0.6396 - val_loss: 0.2667
# Epoch 6/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - Precision: 0.9423 - Recall: 0.8970 - accuracy: 0.9280 - loss: 0.0158 - val_Precision: 0.6762 - val_Recall: 0.6264 - val_accuracy: 0.6377 - val_loss: 0.2668
# Epoch 7/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - Precision: 0.9394 - Recall: 0.9001 - accuracy: 0.9247 - loss: 0.0157 - val_Precision: 0.6768 - val_Recall: 0.6283 - val_accuracy: 0.6396 - val_loss: 0.2672
# Epoch 8/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - Precision: 0.9363 - Recall: 0.8943 - accuracy: 0.9186 - loss: 0.0158 - val_Precision: 0.6728 - val_Recall: 0.6245 - val_accuracy: 0.6434 - val_loss: 0.2692
# Epoch 9/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - Precision: 0.9377 - Recall: 0.8997 - accuracy: 0.9249 - loss: 0.0152 - val_Precision: 0.6784 - val_Recall: 0.6208 - val_accuracy: 0.6434 - val_loss: 0.2754
# Epoch 10/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - Precision: 0.9429 - Recall: 0.9039 - accuracy: 0.9291 - loss: 0.0150 - val_Precision: 0.6735 - val_Recall: 0.6226 - val_accuracy: 0.6396 - val_loss: 0.2706
# Epoch 11/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - Precision: 0.9374 - Recall: 0.8987 - accuracy: 0.9234 - loss: 0.0146 - val_Precision: 0.6734 - val_Recall: 0.6264 - val_accuracy: 0.6377 - val_loss: 0.2689
# Epoch 12/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - Precision: 0.9460 - Recall: 0.9046 - accuracy: 0.9325 - loss: 0.0139 - val_Precision: 0.6667 - val_Recall: 0.6226 - val_accuracy: 0.6396 - val_loss: 0.2721
# Epoch 13/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - Precision: 0.9360 - Recall: 0.8930 - accuracy: 0.9180 - loss: 0.0159 - val_Precision: 0.6673 - val_Recall: 0.6245 - val_accuracy: 0.6377 - val_loss: 0.2710
# Epoch 14/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - Precision: 0.9393 - Recall: 0.9025 - accuracy: 0.9270 - loss: 0.0159 - val_Precision: 0.6673 - val_Recall: 0.6208 - val_accuracy: 0.6358 - val_loss: 0.2722
# Epoch 15/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - Precision: 0.9442 - Recall: 0.9052 - accuracy: 0.9304 - loss: 0.0153 - val_Precision: 0.6714 - val_Recall: 0.6208 - val_accuracy: 0.6396 - val_loss: 0.2735
# Epoch 16/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - Precision: 0.9439 - Recall: 0.9039 - accuracy: 0.9308 - loss: 0.0141 - val_Precision: 0.6734 - val_Recall: 0.6264 - val_accuracy: 0.6396 - val_loss: 0.2739
# Epoch 17/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - Precision: 0.9425 - Recall: 0.9035 - accuracy: 0.9274 - loss: 0.0143 - val_Precision: 0.6747 - val_Recall: 0.6302 - val_accuracy: 0.6415 - val_loss: 0.2721
# Epoch 18/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - Precision: 0.9461 - Recall: 0.9102 - accuracy: 0.9325 - loss: 0.0133 - val_Precision: 0.6735 - val_Recall: 0.6226 - val_accuracy: 0.6434 - val_loss: 0.2764
# Epoch 19/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - Precision: 0.9473 - Recall: 0.9083 - accuracy: 0.9348 - loss: 0.0132 - val_Precision: 0.6728 - val_Recall: 0.6245 - val_accuracy: 0.6415 - val_loss: 0.2748
# Epoch 20/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - Precision: 0.9405 - Recall: 0.9027 - accuracy: 0.9278 - loss: 0.0138 - val_Precision: 0.6728 - val_Recall: 0.6245 - val_accuracy: 0.6396 - val_loss: 0.2790
# Epoch 21/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - Precision: 0.9430 - Recall: 0.9058 - accuracy: 0.9310 - loss: 0.0139 - val_Precision: 0.6701 - val_Recall: 0.6208 - val_accuracy: 0.6415 - val_loss: 0.2757
# Epoch 22/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - Precision: 0.9450 - Recall: 0.9090 - accuracy: 0.9312 - loss: 0.0141 - val_Precision: 0.6714 - val_Recall: 0.6245 - val_accuracy: 0.6358 - val_loss: 0.2760
# Epoch 23/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - Precision: 0.9456 - Recall: 0.9079 - accuracy: 0.9325 - loss: 0.0139 - val_Precision: 0.6667 - val_Recall: 0.6226 - val_accuracy: 0.6396 - val_loss: 0.2756
# Epoch 24/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - Precision: 0.9377 - Recall: 0.8999 - accuracy: 0.9232 - loss: 0.0145 - val_Precision: 0.6673 - val_Recall: 0.6170 - val_accuracy: 0.6453 - val_loss: 0.2857
# Epoch 25/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - Precision: 0.9420 - Recall: 0.8997 - accuracy: 0.9266 - loss: 0.0140 - val_Precision: 0.6748 - val_Recall: 0.6264 - val_accuracy: 0.6377 - val_loss: 0.2808
# Epoch 26/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - Precision: 0.9423 - Recall: 0.9085 - accuracy: 0.9301 - loss: 0.0136 - val_Precision: 0.6768 - val_Recall: 0.6321 - val_accuracy: 0.6377 - val_loss: 0.2772
# Epoch 27/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - Precision: 0.9411 - Recall: 0.9054 - accuracy: 0.9289 - loss: 0.0134 - val_Precision: 0.6795 - val_Recall: 0.6321 - val_accuracy: 0.6415 - val_loss: 0.2779
# Epoch 28/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - Precision: 0.9423 - Recall: 0.9077 - accuracy: 0.9285 - loss: 0.0135 - val_Precision: 0.6789 - val_Recall: 0.6264 - val_accuracy: 0.6415 - val_loss: 0.2797
# Epoch 29/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - Precision: 0.9464 - Recall: 0.9115 - accuracy: 0.9335 - loss: 0.0134 - val_Precision: 0.6714 - val_Recall: 0.6245 - val_accuracy: 0.6340 - val_loss: 0.2796
# Epoch 30/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - Precision: 0.9425 - Recall: 0.9108 - accuracy: 0.9314 - loss: 0.0135 - val_Precision: 0.6727 - val_Recall: 0.6283 - val_accuracy: 0.6377 - val_loss: 0.2792
# Epoch 31/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - Precision: 0.9449 - Recall: 0.9102 - accuracy: 0.9316 - loss: 0.0133 - val_Precision: 0.6721 - val_Recall: 0.6264 - val_accuracy: 0.6358 - val_loss: 0.2775
# Epoch 32/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - Precision: 0.9451 - Recall: 0.9096 - accuracy: 0.9327 - loss: 0.0128 - val_Precision: 0.6667 - val_Recall: 0.6226 - val_accuracy: 0.6377 - val_loss: 0.2811
# Epoch 33/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - Precision: 0.9486 - Recall: 0.9142 - accuracy: 0.9356 - loss: 0.0128 - val_Precision: 0.6694 - val_Recall: 0.6226 - val_accuracy: 0.6321 - val_loss: 0.2803
# Epoch 34/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - Precision: 0.9420 - Recall: 0.9100 - accuracy: 0.9318 - loss: 0.0137 - val_Precision: 0.6640 - val_Recall: 0.6226 - val_accuracy: 0.6321 - val_loss: 0.2811
# Epoch 35/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - Precision: 0.9457 - Recall: 0.9104 - accuracy: 0.9346 - loss: 0.0124 - val_Precision: 0.6640 - val_Recall: 0.6226 - val_accuracy: 0.6340 - val_loss: 0.2825
# Epoch 36/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - Precision: 0.9493 - Recall: 0.9161 - accuracy: 0.9364 - loss: 0.0129 - val_Precision: 0.6714 - val_Recall: 0.6283 - val_accuracy: 0.6377 - val_loss: 0.2812
# Epoch 37/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - Precision: 0.9520 - Recall: 0.9163 - accuracy: 0.9375 - loss: 0.0129 - val_Precision: 0.6680 - val_Recall: 0.6264 - val_accuracy: 0.6377 - val_loss: 0.2815
# Epoch 38/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - Precision: 0.9478 - Recall: 0.9144 - accuracy: 0.9356 - loss: 0.0130 - val_Precision: 0.6714 - val_Recall: 0.6245 - val_accuracy: 0.6377 - val_loss: 0.2854
# Epoch 39/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - Precision: 0.9489 - Recall: 0.9121 - accuracy: 0.9366 - loss: 0.0127 - val_Precision: 0.6707 - val_Recall: 0.6264 - val_accuracy: 0.6396 - val_loss: 0.2861
# Epoch 40/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - Precision: 0.9539 - Recall: 0.9249 - accuracy: 0.9440 - loss: 0.0110 - val_Precision: 0.6680 - val_Recall: 0.6226 - val_accuracy: 0.6396 - val_loss: 0.2851
# Epoch 41/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - Precision: 0.9518 - Recall: 0.9236 - accuracy: 0.9429 - loss: 0.0113 - val_Precision: 0.6667 - val_Recall: 0.6264 - val_accuracy: 0.6377 - val_loss: 0.2837
# Epoch 42/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - Precision: 0.9477 - Recall: 0.9192 - accuracy: 0.9373 - loss: 0.0131 - val_Precision: 0.6640 - val_Recall: 0.6226 - val_accuracy: 0.6377 - val_loss: 0.2843
# Epoch 43/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - Precision: 0.9479 - Recall: 0.9207 - accuracy: 0.9394 - loss: 0.0121 - val_Precision: 0.6667 - val_Recall: 0.6226 - val_accuracy: 0.6340 - val_loss: 0.2900
# Epoch 44/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9460 - Recall: 0.9111 - accuracy: 0.9352 - loss: 0.0128 - val_Precision: 0.6559 - val_Recall: 0.6151 - val_accuracy: 0.6321 - val_loss: 0.2931
# Epoch 45/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9550 - Recall: 0.9226 - accuracy: 0.9427 - loss: 0.0110 - val_Precision: 0.6667 - val_Recall: 0.6226 - val_accuracy: 0.6340 - val_loss: 0.2902
# Epoch 46/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9481 - Recall: 0.9197 - accuracy: 0.9341 - loss: 0.0116 - val_Precision: 0.6627 - val_Recall: 0.6226 - val_accuracy: 0.6321 - val_loss: 0.2886
# Epoch 47/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - Precision: 0.9471 - Recall: 0.9194 - accuracy: 0.9362 - loss: 0.0123 - val_Precision: 0.6606 - val_Recall: 0.6208 - val_accuracy: 0.6358 - val_loss: 0.2865
# Epoch 48/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9505 - Recall: 0.9192 - accuracy: 0.9404 - loss: 0.0116 - val_Precision: 0.6626 - val_Recall: 0.6189 - val_accuracy: 0.6340 - val_loss: 0.2918
# Epoch 49/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9512 - Recall: 0.9232 - accuracy: 0.9417 - loss: 0.0115 - val_Precision: 0.6586 - val_Recall: 0.6189 - val_accuracy: 0.6340 - val_loss: 0.2898
# Epoch 50/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - Precision: 0.9505 - Recall: 0.9180 - accuracy: 0.9385 - loss: 0.0126 - val_Precision: 0.6606 - val_Recall: 0.6208 - val_accuracy: 0.6321 - val_loss: 0.2905
# Epoch 51/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - Precision: 0.9511 - Recall: 0.9222 - accuracy: 0.9429 - loss: 0.0122 - val_Precision: 0.6586 - val_Recall: 0.6189 - val_accuracy: 0.6340 - val_loss: 0.2883
# Epoch 52/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - Precision: 0.9518 - Recall: 0.9205 - accuracy: 0.9385 - loss: 0.0109 - val_Precision: 0.6613 - val_Recall: 0.6189 - val_accuracy: 0.6340 - val_loss: 0.2902
# Epoch 53/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9513 - Recall: 0.9220 - accuracy: 0.9408 - loss: 0.0121 - val_Precision: 0.6647 - val_Recall: 0.6245 - val_accuracy: 0.6321 - val_loss: 0.2934
# Epoch 54/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - Precision: 0.9459 - Recall: 0.9165 - accuracy: 0.9339 - loss: 0.0112 - val_Precision: 0.6620 - val_Recall: 0.6208 - val_accuracy: 0.6321 - val_loss: 0.2926
# Epoch 55/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - Precision: 0.9505 - Recall: 0.9182 - accuracy: 0.9375 - loss: 0.0117 - val_Precision: 0.6567 - val_Recall: 0.6208 - val_accuracy: 0.6340 - val_loss: 0.2897
# Epoch 56/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - Precision: 0.9455 - Recall: 0.9180 - accuracy: 0.9377 - loss: 0.0119 - val_Precision: 0.6613 - val_Recall: 0.6226 - val_accuracy: 0.6321 - val_loss: 0.2908
# Epoch 57/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9479 - Recall: 0.9167 - accuracy: 0.9373 - loss: 0.0127 - val_Precision: 0.6620 - val_Recall: 0.6208 - val_accuracy: 0.6302 - val_loss: 0.2912
# Epoch 58/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - Precision: 0.9517 - Recall: 0.9255 - accuracy: 0.9421 - loss: 0.0111 - val_Precision: 0.6627 - val_Recall: 0.6226 - val_accuracy: 0.6321 - val_loss: 0.2931
# Epoch 59/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9490 - Recall: 0.9176 - accuracy: 0.9398 - loss: 0.0124 - val_Precision: 0.6640 - val_Recall: 0.6226 - val_accuracy: 0.6302 - val_loss: 0.2915
# Epoch 60/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9544 - Recall: 0.9270 - accuracy: 0.9444 - loss: 0.0110 - val_Precision: 0.6640 - val_Recall: 0.6226 - val_accuracy: 0.6283 - val_loss: 0.2943
# Epoch 61/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9555 - Recall: 0.9224 - accuracy: 0.9452 - loss: 0.0105 - val_Precision: 0.6600 - val_Recall: 0.6226 - val_accuracy: 0.6321 - val_loss: 0.2951
# Epoch 62/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9510 - Recall: 0.9249 - accuracy: 0.9434 - loss: 0.0122 - val_Precision: 0.6573 - val_Recall: 0.6189 - val_accuracy: 0.6264 - val_loss: 0.2952
# Epoch 63/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - Precision: 0.9589 - Recall: 0.9310 - accuracy: 0.9494 - loss: 0.0101 - val_Precision: 0.6526 - val_Recall: 0.6132 - val_accuracy: 0.6283 - val_loss: 0.2933
# Epoch 64/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - Precision: 0.9545 - Recall: 0.9245 - accuracy: 0.9434 - loss: 0.0105 - val_Precision: 0.6547 - val_Recall: 0.6189 - val_accuracy: 0.6283 - val_loss: 0.2961
# Epoch 65/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9558 - Recall: 0.9259 - accuracy: 0.9457 - loss: 0.0114 - val_Precision: 0.6547 - val_Recall: 0.6189 - val_accuracy: 0.6321 - val_loss: 0.2955
# Epoch 66/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9546 - Recall: 0.9270 - accuracy: 0.9440 - loss: 0.0111 - val_Precision: 0.6520 - val_Recall: 0.6151 - val_accuracy: 0.6264 - val_loss: 0.2979
# Epoch 67/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9525 - Recall: 0.9245 - accuracy: 0.9429 - loss: 0.0113 - val_Precision: 0.6586 - val_Recall: 0.6189 - val_accuracy: 0.6283 - val_loss: 0.3009
# Epoch 68/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - Precision: 0.9567 - Recall: 0.9310 - accuracy: 0.9482 - loss: 0.0100 - val_Precision: 0.6500 - val_Recall: 0.6132 - val_accuracy: 0.6283 - val_loss: 0.2969
# Epoch 69/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - Precision: 0.9535 - Recall: 0.9283 - accuracy: 0.9442 - loss: 0.0117 - val_Precision: 0.6546 - val_Recall: 0.6151 - val_accuracy: 0.6264 - val_loss: 0.2979
# Epoch 70/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9557 - Recall: 0.9327 - accuracy: 0.9488 - loss: 0.0101 - val_Precision: 0.6586 - val_Recall: 0.6189 - val_accuracy: 0.6264 - val_loss: 0.2994
# Epoch 71/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9551 - Recall: 0.9291 - accuracy: 0.9444 - loss: 0.0115 - val_Precision: 0.6540 - val_Recall: 0.6170 - val_accuracy: 0.6264 - val_loss: 0.2993
# Epoch 72/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9531 - Recall: 0.9289 - accuracy: 0.9446 - loss: 0.0110 - val_Precision: 0.6533 - val_Recall: 0.6151 - val_accuracy: 0.6245 - val_loss: 0.2980
# Epoch 73/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9536 - Recall: 0.9276 - accuracy: 0.9442 - loss: 0.0115 - val_Precision: 0.6647 - val_Recall: 0.6245 - val_accuracy: 0.6302 - val_loss: 0.2997
# Epoch 74/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9533 - Recall: 0.9259 - accuracy: 0.9446 - loss: 0.0111 - val_Precision: 0.6560 - val_Recall: 0.6189 - val_accuracy: 0.6245 - val_loss: 0.2973
# Epoch 75/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9573 - Recall: 0.9312 - accuracy: 0.9482 - loss: 0.0114 - val_Precision: 0.6573 - val_Recall: 0.6189 - val_accuracy: 0.6226 - val_loss: 0.3050
# Epoch 76/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9588 - Recall: 0.9335 - accuracy: 0.9503 - loss: 0.0104 - val_Precision: 0.6593 - val_Recall: 0.6208 - val_accuracy: 0.6226 - val_loss: 0.3022
# Epoch 77/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9575 - Recall: 0.9362 - accuracy: 0.9499 - loss: 0.0098 - val_Precision: 0.6606 - val_Recall: 0.6208 - val_accuracy: 0.6283 - val_loss: 0.3033
# Epoch 78/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9638 - Recall: 0.9371 - accuracy: 0.9528 - loss: 0.0092 - val_Precision: 0.6560 - val_Recall: 0.6189 - val_accuracy: 0.6264 - val_loss: 0.3057
# Epoch 79/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9537 - Recall: 0.9333 - accuracy: 0.9467 - loss: 0.0102 - val_Precision: 0.6554 - val_Recall: 0.6208 - val_accuracy: 0.6283 - val_loss: 0.3131
# Epoch 80/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9537 - Recall: 0.9335 - accuracy: 0.9455 - loss: 0.0101 - val_Precision: 0.6613 - val_Recall: 0.6226 - val_accuracy: 0.6302 - val_loss: 0.3057
# Epoch 81/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9624 - Recall: 0.9385 - accuracy: 0.9528 - loss: 0.0101 - val_Precision: 0.6620 - val_Recall: 0.6208 - val_accuracy: 0.6283 - val_loss: 0.3051
# Epoch 82/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9595 - Recall: 0.9337 - accuracy: 0.9505 - loss: 0.0106 - val_Precision: 0.6567 - val_Recall: 0.6208 - val_accuracy: 0.6302 - val_loss: 0.3048
# Epoch 83/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9526 - Recall: 0.9308 - accuracy: 0.9467 - loss: 0.0105 - val_Precision: 0.6606 - val_Recall: 0.6208 - val_accuracy: 0.6321 - val_loss: 0.3092
# Epoch 84/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9587 - Recall: 0.9350 - accuracy: 0.9484 - loss: 0.0103 - val_Precision: 0.6566 - val_Recall: 0.6170 - val_accuracy: 0.6264 - val_loss: 0.3079
# Epoch 85/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9593 - Recall: 0.9387 - accuracy: 0.9526 - loss: 0.0092 - val_Precision: 0.6514 - val_Recall: 0.6170 - val_accuracy: 0.6245 - val_loss: 0.3117
# Epoch 86/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9586 - Recall: 0.9335 - accuracy: 0.9513 - loss: 0.0101 - val_Precision: 0.6520 - val_Recall: 0.6151 - val_accuracy: 0.6264 - val_loss: 0.3117
# Epoch 87/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9565 - Recall: 0.9322 - accuracy: 0.9471 - loss: 0.0096 - val_Precision: 0.6580 - val_Recall: 0.6208 - val_accuracy: 0.6302 - val_loss: 0.3087
# Epoch 88/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9566 - Recall: 0.9339 - accuracy: 0.9476 - loss: 0.0102 - val_Precision: 0.6600 - val_Recall: 0.6189 - val_accuracy: 0.6321 - val_loss: 0.3064
# Epoch 89/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - Precision: 0.9581 - Recall: 0.9362 - accuracy: 0.9490 - loss: 0.0097 - val_Precision: 0.6560 - val_Recall: 0.6189 - val_accuracy: 0.6340 - val_loss: 0.3091
# Epoch 90/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - Precision: 0.9584 - Recall: 0.9366 - accuracy: 0.9511 - loss: 0.0101 - val_Precision: 0.6606 - val_Recall: 0.6170 - val_accuracy: 0.6283 - val_loss: 0.3099
# Epoch 91/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - Precision: 0.9632 - Recall: 0.9394 - accuracy: 0.9555 - loss: 0.0095 - val_Precision: 0.6633 - val_Recall: 0.6245 - val_accuracy: 0.6340 - val_loss: 0.3077
# Epoch 92/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9594 - Recall: 0.9413 - accuracy: 0.9536 - loss: 0.0091 - val_Precision: 0.6647 - val_Recall: 0.6245 - val_accuracy: 0.6358 - val_loss: 0.3124
# Epoch 93/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9602 - Recall: 0.9413 - accuracy: 0.9541 - loss: 0.0094 - val_Precision: 0.6600 - val_Recall: 0.6226 - val_accuracy: 0.6302 - val_loss: 0.3096
# Epoch 94/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9631 - Recall: 0.9404 - accuracy: 0.9528 - loss: 0.0103 - val_Precision: 0.6580 - val_Recall: 0.6208 - val_accuracy: 0.6321 - val_loss: 0.3116
# Epoch 95/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9618 - Recall: 0.9394 - accuracy: 0.9534 - loss: 0.0089 - val_Precision: 0.6520 - val_Recall: 0.6151 - val_accuracy: 0.6208 - val_loss: 0.3145
# Epoch 96/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9582 - Recall: 0.9415 - accuracy: 0.9513 - loss: 0.0092 - val_Precision: 0.6586 - val_Recall: 0.6189 - val_accuracy: 0.6264 - val_loss: 0.3128
# Epoch 97/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9595 - Recall: 0.9354 - accuracy: 0.9499 - loss: 0.0097 - val_Precision: 0.6533 - val_Recall: 0.6151 - val_accuracy: 0.6226 - val_loss: 0.3167
# Epoch 98/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - Precision: 0.9560 - Recall: 0.9354 - accuracy: 0.9501 - loss: 0.0095 - val_Precision: 0.6546 - val_Recall: 0.6151 - val_accuracy: 0.6245 - val_loss: 0.3160
# Epoch 99/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - Precision: 0.9647 - Recall: 0.9455 - accuracy: 0.9583 - loss: 0.0098 - val_Precision: 0.6514 - val_Recall: 0.6170 - val_accuracy: 0.6245 - val_loss: 0.3158
# Epoch 100/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9607 - Recall: 0.9375 - accuracy: 0.9503 - loss: 0.0092 - val_Precision: 0.6520 - val_Recall: 0.6151 - val_accuracy: 0.6264 - val_loss: 0.3156
# Epoch 101/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9618 - Recall: 0.9398 - accuracy: 0.9534 - loss: 0.0098 - val_Precision: 0.6494 - val_Recall: 0.6151 - val_accuracy: 0.6226 - val_loss: 0.3209
# Epoch 102/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9619 - Recall: 0.9421 - accuracy: 0.9536 - loss: 0.0091 - val_Precision: 0.6507 - val_Recall: 0.6151 - val_accuracy: 0.6245 - val_loss: 0.3171
# Epoch 103/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9635 - Recall: 0.9419 - accuracy: 0.9564 - loss: 0.0086 - val_Precision: 0.6547 - val_Recall: 0.6189 - val_accuracy: 0.6245 - val_loss: 0.3160
# Epoch 104/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9615 - Recall: 0.9381 - accuracy: 0.9524 - loss: 0.0086 - val_Precision: 0.6527 - val_Recall: 0.6170 - val_accuracy: 0.6245 - val_loss: 0.3184
# Epoch 105/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9576 - Recall: 0.9371 - accuracy: 0.9532 - loss: 0.0093 - val_Precision: 0.6561 - val_Recall: 0.6226 - val_accuracy: 0.6321 - val_loss: 0.3130
# Epoch 106/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9606 - Recall: 0.9417 - accuracy: 0.9534 - loss: 0.0094 - val_Precision: 0.6554 - val_Recall: 0.6208 - val_accuracy: 0.6283 - val_loss: 0.3190
# Epoch 107/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9619 - Recall: 0.9432 - accuracy: 0.9551 - loss: 0.0098 - val_Precision: 0.6534 - val_Recall: 0.6189 - val_accuracy: 0.6264 - val_loss: 0.3242
# Epoch 108/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9599 - Recall: 0.9400 - accuracy: 0.9538 - loss: 0.0092 - val_Precision: 0.6560 - val_Recall: 0.6189 - val_accuracy: 0.6226 - val_loss: 0.3192
# Epoch 109/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9628 - Recall: 0.9392 - accuracy: 0.9534 - loss: 0.0091 - val_Precision: 0.6554 - val_Recall: 0.6208 - val_accuracy: 0.6321 - val_loss: 0.3206
# Epoch 110/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9618 - Recall: 0.9444 - accuracy: 0.9568 - loss: 0.0095 - val_Precision: 0.6528 - val_Recall: 0.6208 - val_accuracy: 0.6264 - val_loss: 0.3212
# Epoch 111/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9653 - Recall: 0.9459 - accuracy: 0.9587 - loss: 0.0083 - val_Precision: 0.6515 - val_Recall: 0.6208 - val_accuracy: 0.6264 - val_loss: 0.3240
# Epoch 112/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9602 - Recall: 0.9375 - accuracy: 0.9536 - loss: 0.0095 - val_Precision: 0.6515 - val_Recall: 0.6208 - val_accuracy: 0.6264 - val_loss: 0.3263
# Epoch 113/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - Precision: 0.9615 - Recall: 0.9425 - accuracy: 0.9553 - loss: 0.0086 - val_Precision: 0.6561 - val_Recall: 0.6226 - val_accuracy: 0.6283 - val_loss: 0.3241
# Epoch 114/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9669 - Recall: 0.9484 - accuracy: 0.9595 - loss: 0.0087 - val_Precision: 0.6509 - val_Recall: 0.6226 - val_accuracy: 0.6264 - val_loss: 0.3263
# Epoch 115/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - Precision: 0.9608 - Recall: 0.9411 - accuracy: 0.9528 - loss: 0.0092 - val_Precision: 0.6534 - val_Recall: 0.6189 - val_accuracy: 0.6226 - val_loss: 0.3211
# Epoch 116/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9610 - Recall: 0.9404 - accuracy: 0.9518 - loss: 0.0092 - val_Precision: 0.6488 - val_Recall: 0.6170 - val_accuracy: 0.6226 - val_loss: 0.3245
# Epoch 117/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9628 - Recall: 0.9442 - accuracy: 0.9564 - loss: 0.0080 - val_Precision: 0.6502 - val_Recall: 0.6208 - val_accuracy: 0.6245 - val_loss: 0.3276
# Epoch 118/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9632 - Recall: 0.9452 - accuracy: 0.9576 - loss: 0.0086 - val_Precision: 0.6487 - val_Recall: 0.6132 - val_accuracy: 0.6245 - val_loss: 0.3257
# Epoch 119/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9613 - Recall: 0.9421 - accuracy: 0.9545 - loss: 0.0091 - val_Precision: 0.6443 - val_Recall: 0.6151 - val_accuracy: 0.6189 - val_loss: 0.3305
# Epoch 120/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9662 - Recall: 0.9486 - accuracy: 0.9616 - loss: 0.0081 - val_Precision: 0.6450 - val_Recall: 0.6170 - val_accuracy: 0.6245 - val_loss: 0.3345
# Epoch 121/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9633 - Recall: 0.9461 - accuracy: 0.9564 - loss: 0.0081 - val_Precision: 0.6528 - val_Recall: 0.6208 - val_accuracy: 0.6264 - val_loss: 0.3297
# Epoch 122/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9658 - Recall: 0.9490 - accuracy: 0.9608 - loss: 0.0083 - val_Precision: 0.6541 - val_Recall: 0.6208 - val_accuracy: 0.6264 - val_loss: 0.3285
# Epoch 123/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9670 - Recall: 0.9520 - accuracy: 0.9612 - loss: 0.0077 - val_Precision: 0.6514 - val_Recall: 0.6170 - val_accuracy: 0.6245 - val_loss: 0.3306
# Epoch 124/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9641 - Recall: 0.9476 - accuracy: 0.9587 - loss: 0.0087 - val_Precision: 0.6508 - val_Recall: 0.6189 - val_accuracy: 0.6208 - val_loss: 0.3243
# Epoch 125/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9656 - Recall: 0.9469 - accuracy: 0.9580 - loss: 0.0079 - val_Precision: 0.6488 - val_Recall: 0.6170 - val_accuracy: 0.6208 - val_loss: 0.3307
# Epoch 126/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9637 - Recall: 0.9457 - accuracy: 0.9580 - loss: 0.0085 - val_Precision: 0.6528 - val_Recall: 0.6208 - val_accuracy: 0.6264 - val_loss: 0.3313
# Epoch 127/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9658 - Recall: 0.9492 - accuracy: 0.9591 - loss: 0.0082 - val_Precision: 0.6535 - val_Recall: 0.6226 - val_accuracy: 0.6264 - val_loss: 0.3274
# Epoch 128/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9674 - Recall: 0.9469 - accuracy: 0.9587 - loss: 0.0083 - val_Precision: 0.6450 - val_Recall: 0.6170 - val_accuracy: 0.6264 - val_loss: 0.3331
# Epoch 129/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9668 - Recall: 0.9461 - accuracy: 0.9595 - loss: 0.0082 - val_Precision: 0.6540 - val_Recall: 0.6170 - val_accuracy: 0.6208 - val_loss: 0.3273
# Epoch 130/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9678 - Recall: 0.9507 - accuracy: 0.9614 - loss: 0.0078 - val_Precision: 0.6501 - val_Recall: 0.6170 - val_accuracy: 0.6226 - val_loss: 0.3300
# Epoch 131/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9712 - Recall: 0.9543 - accuracy: 0.9654 - loss: 0.0075 - val_Precision: 0.6482 - val_Recall: 0.6189 - val_accuracy: 0.6245 - val_loss: 0.3332
# Epoch 132/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9670 - Recall: 0.9522 - accuracy: 0.9612 - loss: 0.0075 - val_Precision: 0.6488 - val_Recall: 0.6170 - val_accuracy: 0.6189 - val_loss: 0.3328
# Epoch 133/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9682 - Recall: 0.9509 - accuracy: 0.9616 - loss: 0.0077 - val_Precision: 0.6444 - val_Recall: 0.6189 - val_accuracy: 0.6226 - val_loss: 0.3373
# Epoch 134/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9667 - Recall: 0.9509 - accuracy: 0.9610 - loss: 0.0072 - val_Precision: 0.6444 - val_Recall: 0.6189 - val_accuracy: 0.6226 - val_loss: 0.3382
# Epoch 135/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9652 - Recall: 0.9480 - accuracy: 0.9601 - loss: 0.0078 - val_Precision: 0.6495 - val_Recall: 0.6189 - val_accuracy: 0.6245 - val_loss: 0.3334
# Epoch 136/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - Precision: 0.9638 - Recall: 0.9486 - accuracy: 0.9593 - loss: 0.0079 - val_Precision: 0.6468 - val_Recall: 0.6151 - val_accuracy: 0.6226 - val_loss: 0.3368
# Epoch 137/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - Precision: 0.9672 - Recall: 0.9520 - accuracy: 0.9625 - loss: 0.0088 - val_Precision: 0.6501 - val_Recall: 0.6170 - val_accuracy: 0.6208 - val_loss: 0.3339
# Epoch 138/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - Precision: 0.9631 - Recall: 0.9467 - accuracy: 0.9568 - loss: 0.0084 - val_Precision: 0.6521 - val_Recall: 0.6189 - val_accuracy: 0.6226 - val_loss: 0.3305
# Epoch 139/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9652 - Recall: 0.9473 - accuracy: 0.9597 - loss: 0.0082 - val_Precision: 0.6502 - val_Recall: 0.6208 - val_accuracy: 0.6264 - val_loss: 0.3351
# Epoch 140/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9644 - Recall: 0.9482 - accuracy: 0.9587 - loss: 0.0087 - val_Precision: 0.6443 - val_Recall: 0.6151 - val_accuracy: 0.6208 - val_loss: 0.3352
# Epoch 141/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9654 - Recall: 0.9476 - accuracy: 0.9595 - loss: 0.0083 - val_Precision: 0.6471 - val_Recall: 0.6226 - val_accuracy: 0.6264 - val_loss: 0.3366
# Epoch 142/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9673 - Recall: 0.9497 - accuracy: 0.9601 - loss: 0.0074 - val_Precision: 0.6438 - val_Recall: 0.6208 - val_accuracy: 0.6245 - val_loss: 0.3389
# Epoch 143/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9683 - Recall: 0.9545 - accuracy: 0.9635 - loss: 0.0076 - val_Precision: 0.6443 - val_Recall: 0.6151 - val_accuracy: 0.6226 - val_loss: 0.3345
# Epoch 144/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - Precision: 0.9641 - Recall: 0.9476 - accuracy: 0.9604 - loss: 0.0082 - val_Precision: 0.6387 - val_Recall: 0.6170 - val_accuracy: 0.6226 - val_loss: 0.3392
# Epoch 145/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9648 - Recall: 0.9484 - accuracy: 0.9587 - loss: 0.0081 - val_Precision: 0.6374 - val_Recall: 0.6170 - val_accuracy: 0.6226 - val_loss: 0.3385
# Epoch 146/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9673 - Recall: 0.9499 - accuracy: 0.9608 - loss: 0.0076 - val_Precision: 0.6365 - val_Recall: 0.6113 - val_accuracy: 0.6208 - val_loss: 0.3389
# Epoch 147/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9666 - Recall: 0.9545 - accuracy: 0.9622 - loss: 0.0071 - val_Precision: 0.6403 - val_Recall: 0.6113 - val_accuracy: 0.6170 - val_loss: 0.3380
# Epoch 148/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9686 - Recall: 0.9499 - accuracy: 0.9627 - loss: 0.0078 - val_Precision: 0.6385 - val_Recall: 0.6132 - val_accuracy: 0.6170 - val_loss: 0.3343
# Epoch 149/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9686 - Recall: 0.9522 - accuracy: 0.9627 - loss: 0.0076 - val_Precision: 0.6430 - val_Recall: 0.6151 - val_accuracy: 0.6189 - val_loss: 0.3332
# Epoch 150/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - Precision: 0.9695 - Recall: 0.9547 - accuracy: 0.9652 - loss: 0.0070 - val_Precision: 0.6392 - val_Recall: 0.6151 - val_accuracy: 0.6208 - val_loss: 0.3360
# Epoch 151/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9706 - Recall: 0.9572 - accuracy: 0.9662 - loss: 0.0074 - val_Precision: 0.6385 - val_Recall: 0.6132 - val_accuracy: 0.6170 - val_loss: 0.3363
# Epoch 152/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - Precision: 0.9691 - Recall: 0.9547 - accuracy: 0.9645 - loss: 0.0074 - val_Precision: 0.6424 - val_Recall: 0.6170 - val_accuracy: 0.6226 - val_loss: 0.3349
# Epoch 153/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9662 - Recall: 0.9471 - accuracy: 0.9585 - loss: 0.0081 - val_Precision: 0.6373 - val_Recall: 0.6132 - val_accuracy: 0.6208 - val_loss: 0.3386
# Epoch 154/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9708 - Recall: 0.9547 - accuracy: 0.9639 - loss: 0.0069 - val_Precision: 0.6367 - val_Recall: 0.6151 - val_accuracy: 0.6208 - val_loss: 0.3421
# Epoch 155/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - Precision: 0.9690 - Recall: 0.9572 - accuracy: 0.9645 - loss: 0.0076 - val_Precision: 0.6373 - val_Recall: 0.6132 - val_accuracy: 0.6189 - val_loss: 0.3399
# Epoch 156/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - Precision: 0.9668 - Recall: 0.9522 - accuracy: 0.9627 - loss: 0.0074 - val_Precision: 0.6385 - val_Recall: 0.6132 - val_accuracy: 0.6189 - val_loss: 0.3417
# Epoch 157/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9716 - Recall: 0.9541 - accuracy: 0.9656 - loss: 0.0074 - val_Precision: 0.6360 - val_Recall: 0.6132 - val_accuracy: 0.6208 - val_loss: 0.3425
# Epoch 158/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - Precision: 0.9704 - Recall: 0.9562 - accuracy: 0.9652 - loss: 0.0069 - val_Precision: 0.6392 - val_Recall: 0.6151 - val_accuracy: 0.6170 - val_loss: 0.3400
# Epoch 159/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9709 - Recall: 0.9528 - accuracy: 0.9639 - loss: 0.0077 - val_Precision: 0.6291 - val_Recall: 0.6113 - val_accuracy: 0.6151 - val_loss: 0.3437
# Epoch 160/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9667 - Recall: 0.9511 - accuracy: 0.9599 - loss: 0.0078 - val_Precision: 0.6348 - val_Recall: 0.6132 - val_accuracy: 0.6189 - val_loss: 0.3430
# Epoch 161/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - Precision: 0.9730 - Recall: 0.9614 - accuracy: 0.9694 - loss: 0.0061 - val_Precision: 0.6304 - val_Recall: 0.6113 - val_accuracy: 0.6170 - val_loss: 0.3436
# Epoch 162/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9706 - Recall: 0.9543 - accuracy: 0.9669 - loss: 0.0065 - val_Precision: 0.6341 - val_Recall: 0.6113 - val_accuracy: 0.6189 - val_loss: 0.3423
# Epoch 163/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9692 - Recall: 0.9572 - accuracy: 0.9648 - loss: 0.0072 - val_Precision: 0.6458 - val_Recall: 0.6226 - val_accuracy: 0.6283 - val_loss: 0.3422
# Epoch 164/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9692 - Recall: 0.9576 - accuracy: 0.9650 - loss: 0.0075 - val_Precision: 0.6318 - val_Recall: 0.6151 - val_accuracy: 0.6189 - val_loss: 0.3463
# Epoch 165/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9700 - Recall: 0.9559 - accuracy: 0.9662 - loss: 0.0072 - val_Precision: 0.6348 - val_Recall: 0.6132 - val_accuracy: 0.6226 - val_loss: 0.3415
# Epoch 166/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - Precision: 0.9711 - Recall: 0.9574 - accuracy: 0.9675 - loss: 0.0067 - val_Precision: 0.6380 - val_Recall: 0.6151 - val_accuracy: 0.6226 - val_loss: 0.3431
# Epoch 167/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9719 - Recall: 0.9578 - accuracy: 0.9666 - loss: 0.0071 - val_Precision: 0.6330 - val_Recall: 0.6151 - val_accuracy: 0.6226 - val_loss: 0.3458
# Epoch 168/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9729 - Recall: 0.9574 - accuracy: 0.9675 - loss: 0.0071 - val_Precision: 0.6342 - val_Recall: 0.6151 - val_accuracy: 0.6208 - val_loss: 0.3446
# Epoch 169/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9693 - Recall: 0.9545 - accuracy: 0.9633 - loss: 0.0079 - val_Precision: 0.6362 - val_Recall: 0.6170 - val_accuracy: 0.6189 - val_loss: 0.3425
# Epoch 170/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9702 - Recall: 0.9568 - accuracy: 0.9654 - loss: 0.0076 - val_Precision: 0.6323 - val_Recall: 0.6132 - val_accuracy: 0.6208 - val_loss: 0.3465
# Epoch 171/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9719 - Recall: 0.9572 - accuracy: 0.9660 - loss: 0.0069 - val_Precision: 0.6311 - val_Recall: 0.6132 - val_accuracy: 0.6170 - val_loss: 0.3483
# Epoch 172/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9649 - Recall: 0.9503 - accuracy: 0.9601 - loss: 0.0084 - val_Precision: 0.6328 - val_Recall: 0.6113 - val_accuracy: 0.6189 - val_loss: 0.3463
# Epoch 173/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9716 - Recall: 0.9612 - accuracy: 0.9685 - loss: 0.0070 - val_Precision: 0.6353 - val_Recall: 0.6113 - val_accuracy: 0.6170 - val_loss: 0.3489
# Epoch 174/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9716 - Recall: 0.9553 - accuracy: 0.9650 - loss: 0.0063 - val_Precision: 0.6355 - val_Recall: 0.6151 - val_accuracy: 0.6170 - val_loss: 0.3459
# Epoch 175/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9716 - Recall: 0.9604 - accuracy: 0.9664 - loss: 0.0067 - val_Precision: 0.6380 - val_Recall: 0.6151 - val_accuracy: 0.6170 - val_loss: 0.3471
# Epoch 176/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9696 - Recall: 0.9576 - accuracy: 0.9656 - loss: 0.0067 - val_Precision: 0.6374 - val_Recall: 0.6170 - val_accuracy: 0.6189 - val_loss: 0.3435
# Epoch 177/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9728 - Recall: 0.9595 - accuracy: 0.9694 - loss: 0.0064 - val_Precision: 0.6353 - val_Recall: 0.6113 - val_accuracy: 0.6170 - val_loss: 0.3453
# Epoch 178/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9726 - Recall: 0.9593 - accuracy: 0.9687 - loss: 0.0062 - val_Precision: 0.6333 - val_Recall: 0.6094 - val_accuracy: 0.6170 - val_loss: 0.3470
# Epoch 179/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9687 - Recall: 0.9555 - accuracy: 0.9633 - loss: 0.0071 - val_Precision: 0.6291 - val_Recall: 0.6113 - val_accuracy: 0.6132 - val_loss: 0.3534
# Epoch 180/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9701 - Recall: 0.9541 - accuracy: 0.9643 - loss: 0.0065 - val_Precision: 0.6348 - val_Recall: 0.6132 - val_accuracy: 0.6170 - val_loss: 0.3523
# Epoch 181/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9734 - Recall: 0.9610 - accuracy: 0.9681 - loss: 0.0063 - val_Precision: 0.6385 - val_Recall: 0.6132 - val_accuracy: 0.6132 - val_loss: 0.3512
# Epoch 182/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9698 - Recall: 0.9572 - accuracy: 0.9648 - loss: 0.0069 - val_Precision: 0.6335 - val_Recall: 0.6132 - val_accuracy: 0.6170 - val_loss: 0.3520
# Epoch 183/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9744 - Recall: 0.9595 - accuracy: 0.9692 - loss: 0.0058 - val_Precision: 0.6341 - val_Recall: 0.6113 - val_accuracy: 0.6132 - val_loss: 0.3520
# Epoch 184/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9716 - Recall: 0.9618 - accuracy: 0.9671 - loss: 0.0066 - val_Precision: 0.6353 - val_Recall: 0.6113 - val_accuracy: 0.6170 - val_loss: 0.3528
# Epoch 185/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9738 - Recall: 0.9604 - accuracy: 0.9681 - loss: 0.0059 - val_Precision: 0.6314 - val_Recall: 0.6075 - val_accuracy: 0.6151 - val_loss: 0.3538
# Epoch 186/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9716 - Recall: 0.9612 - accuracy: 0.9681 - loss: 0.0068 - val_Precision: 0.6348 - val_Recall: 0.6132 - val_accuracy: 0.6208 - val_loss: 0.3535
# Epoch 187/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9729 - Recall: 0.9635 - accuracy: 0.9685 - loss: 0.0071 - val_Precision: 0.6346 - val_Recall: 0.6094 - val_accuracy: 0.6170 - val_loss: 0.3536
# Epoch 188/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9707 - Recall: 0.9576 - accuracy: 0.9652 - loss: 0.0066 - val_Precision: 0.6333 - val_Recall: 0.6094 - val_accuracy: 0.6170 - val_loss: 0.3538
# Epoch 189/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9718 - Recall: 0.9604 - accuracy: 0.9677 - loss: 0.0066 - val_Precision: 0.6299 - val_Recall: 0.6038 - val_accuracy: 0.6094 - val_loss: 0.3544
# Epoch 190/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9713 - Recall: 0.9580 - accuracy: 0.9664 - loss: 0.0069 - val_Precision: 0.6250 - val_Recall: 0.6038 - val_accuracy: 0.6094 - val_loss: 0.3576
# Epoch 191/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9739 - Recall: 0.9620 - accuracy: 0.9687 - loss: 0.0066 - val_Precision: 0.6289 - val_Recall: 0.6075 - val_accuracy: 0.6170 - val_loss: 0.3539
# Epoch 192/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9700 - Recall: 0.9572 - accuracy: 0.9654 - loss: 0.0069 - val_Precision: 0.6289 - val_Recall: 0.6075 - val_accuracy: 0.6113 - val_loss: 0.3562
# Epoch 193/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9693 - Recall: 0.9551 - accuracy: 0.9650 - loss: 0.0071 - val_Precision: 0.6306 - val_Recall: 0.6057 - val_accuracy: 0.6094 - val_loss: 0.3578
# Epoch 194/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9764 - Recall: 0.9654 - accuracy: 0.9727 - loss: 0.0057 - val_Precision: 0.6282 - val_Recall: 0.6057 - val_accuracy: 0.6075 - val_loss: 0.3565
# Epoch 195/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9737 - Recall: 0.9616 - accuracy: 0.9711 - loss: 0.0061 - val_Precision: 0.6301 - val_Recall: 0.6075 - val_accuracy: 0.6132 - val_loss: 0.3564
# Epoch 196/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - Precision: 0.9705 - Recall: 0.9580 - accuracy: 0.9664 - loss: 0.0066 - val_Precision: 0.6277 - val_Recall: 0.6075 - val_accuracy: 0.6113 - val_loss: 0.3583
# Epoch 197/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9696 - Recall: 0.9580 - accuracy: 0.9658 - loss: 0.0063 - val_Precision: 0.6296 - val_Recall: 0.6094 - val_accuracy: 0.6113 - val_loss: 0.3544
# Epoch 198/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9756 - Recall: 0.9660 - accuracy: 0.9713 - loss: 0.0062 - val_Precision: 0.6265 - val_Recall: 0.6075 - val_accuracy: 0.6113 - val_loss: 0.3580
# Epoch 199/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9735 - Recall: 0.9631 - accuracy: 0.9700 - loss: 0.0062 - val_Precision: 0.6289 - val_Recall: 0.6075 - val_accuracy: 0.6094 - val_loss: 0.3561
# Epoch 200/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9730 - Recall: 0.9610 - accuracy: 0.9690 - loss: 0.0067 - val_Precision: 0.6277 - val_Recall: 0.6075 - val_accuracy: 0.6094 - val_loss: 0.3598
# Epoch 201/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9735 - Recall: 0.9639 - accuracy: 0.9700 - loss: 0.0062 - val_Precision: 0.6214 - val_Recall: 0.6038 - val_accuracy: 0.6075 - val_loss: 0.3630
# Epoch 202/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9702 - Recall: 0.9625 - accuracy: 0.9675 - loss: 0.0075 - val_Precision: 0.6267 - val_Recall: 0.6019 - val_accuracy: 0.6132 - val_loss: 0.3701
# Epoch 203/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9741 - Recall: 0.9627 - accuracy: 0.9711 - loss: 0.0056 - val_Precision: 0.6265 - val_Recall: 0.6075 - val_accuracy: 0.6113 - val_loss: 0.3613
# Epoch 204/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9720 - Recall: 0.9620 - accuracy: 0.9679 - loss: 0.0069 - val_Precision: 0.6233 - val_Recall: 0.6057 - val_accuracy: 0.6094 - val_loss: 0.3614
# Epoch 205/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9753 - Recall: 0.9627 - accuracy: 0.9713 - loss: 0.0061 - val_Precision: 0.6238 - val_Recall: 0.6038 - val_accuracy: 0.6113 - val_loss: 0.3670
# Epoch 206/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9744 - Recall: 0.9643 - accuracy: 0.9715 - loss: 0.0061 - val_Precision: 0.6284 - val_Recall: 0.6094 - val_accuracy: 0.6189 - val_loss: 0.3636
# Epoch 207/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9701 - Recall: 0.9595 - accuracy: 0.9666 - loss: 0.0068 - val_Precision: 0.6316 - val_Recall: 0.6113 - val_accuracy: 0.6151 - val_loss: 0.3604
# Epoch 208/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9758 - Recall: 0.9639 - accuracy: 0.9713 - loss: 0.0058 - val_Precision: 0.6260 - val_Recall: 0.6094 - val_accuracy: 0.6113 - val_loss: 0.3635
# Epoch 209/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9708 - Recall: 0.9620 - accuracy: 0.9679 - loss: 0.0072 - val_Precision: 0.6284 - val_Recall: 0.6094 - val_accuracy: 0.6132 - val_loss: 0.3669
# Epoch 210/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9756 - Recall: 0.9633 - accuracy: 0.9702 - loss: 0.0059 - val_Precision: 0.6248 - val_Recall: 0.6094 - val_accuracy: 0.6113 - val_loss: 0.3660
# Epoch 211/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9746 - Recall: 0.9643 - accuracy: 0.9698 - loss: 0.0061 - val_Precision: 0.6260 - val_Recall: 0.6094 - val_accuracy: 0.6132 - val_loss: 0.3591
# Epoch 212/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9735 - Recall: 0.9616 - accuracy: 0.9690 - loss: 0.0059 - val_Precision: 0.6255 - val_Recall: 0.6113 - val_accuracy: 0.6132 - val_loss: 0.3656
# Epoch 213/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9710 - Recall: 0.9612 - accuracy: 0.9673 - loss: 0.0068 - val_Precision: 0.6309 - val_Recall: 0.6094 - val_accuracy: 0.6170 - val_loss: 0.3659
# Epoch 214/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9745 - Recall: 0.9620 - accuracy: 0.9700 - loss: 0.0059 - val_Precision: 0.6272 - val_Recall: 0.6094 - val_accuracy: 0.6170 - val_loss: 0.3661
# Epoch 215/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9758 - Recall: 0.9660 - accuracy: 0.9706 - loss: 0.0061 - val_Precision: 0.6304 - val_Recall: 0.6113 - val_accuracy: 0.6170 - val_loss: 0.3647
# Epoch 216/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9748 - Recall: 0.9639 - accuracy: 0.9704 - loss: 0.0066 - val_Precision: 0.6260 - val_Recall: 0.6094 - val_accuracy: 0.6170 - val_loss: 0.3668
# Epoch 217/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9750 - Recall: 0.9652 - accuracy: 0.9717 - loss: 0.0063 - val_Precision: 0.6316 - val_Recall: 0.6113 - val_accuracy: 0.6151 - val_loss: 0.3657
# Epoch 218/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9754 - Recall: 0.9650 - accuracy: 0.9717 - loss: 0.0062 - val_Precision: 0.6296 - val_Recall: 0.6094 - val_accuracy: 0.6132 - val_loss: 0.3638
# Epoch 219/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9765 - Recall: 0.9673 - accuracy: 0.9734 - loss: 0.0062 - val_Precision: 0.6265 - val_Recall: 0.6075 - val_accuracy: 0.6151 - val_loss: 0.3625
# Epoch 220/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9767 - Recall: 0.9658 - accuracy: 0.9717 - loss: 0.0059 - val_Precision: 0.6311 - val_Recall: 0.6132 - val_accuracy: 0.6151 - val_loss: 0.3626
# Epoch 221/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9752 - Recall: 0.9645 - accuracy: 0.9723 - loss: 0.0065 - val_Precision: 0.6335 - val_Recall: 0.6132 - val_accuracy: 0.6170 - val_loss: 0.3674
# Epoch 222/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9777 - Recall: 0.9677 - accuracy: 0.9723 - loss: 0.0059 - val_Precision: 0.6284 - val_Recall: 0.6094 - val_accuracy: 0.6151 - val_loss: 0.3645
# Epoch 223/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9752 - Recall: 0.9645 - accuracy: 0.9715 - loss: 0.0057 - val_Precision: 0.6252 - val_Recall: 0.6075 - val_accuracy: 0.6113 - val_loss: 0.3688
# Epoch 224/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9748 - Recall: 0.9645 - accuracy: 0.9706 - loss: 0.0056 - val_Precision: 0.6252 - val_Recall: 0.6075 - val_accuracy: 0.6113 - val_loss: 0.3643
# Epoch 225/1000
# ...
# Epoch 928/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9937 - Recall: 0.9927 - accuracy: 0.9931 - loss: 0.0019 - val_Precision: 0.5958 - val_Recall: 0.5868 - val_accuracy: 0.5887 - val_loss: 0.5623
# Epoch 929/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9952 - Recall: 0.9920 - accuracy: 0.9935 - loss: 0.0017 - val_Precision: 0.5988 - val_Recall: 0.5887 - val_accuracy: 0.5925 - val_loss: 0.5536
# Epoch 930/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9926 - Recall: 0.9901 - accuracy: 0.9914 - loss: 0.0018 - val_Precision: 0.6000 - val_Recall: 0.5887 - val_accuracy: 0.5906 - val_loss: 0.5620
# Epoch 931/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9960 - Recall: 0.9935 - accuracy: 0.9952 - loss: 0.0017 - val_Precision: 0.6000 - val_Recall: 0.5887 - val_accuracy: 0.5906 - val_loss: 0.5625
# Epoch 932/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9933 - Recall: 0.9922 - accuracy: 0.9931 - loss: 0.0014 - val_Precision: 0.5992 - val_Recall: 0.5868 - val_accuracy: 0.5906 - val_loss: 0.5585
# Epoch 933/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9931 - Recall: 0.9908 - accuracy: 0.9918 - loss: 0.0021 - val_Precision: 0.6012 - val_Recall: 0.5887 - val_accuracy: 0.5925 - val_loss: 0.5585
# Epoch 934/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9922 - Recall: 0.9895 - accuracy: 0.9904 - loss: 0.0023 - val_Precision: 0.5973 - val_Recall: 0.5849 - val_accuracy: 0.5906 - val_loss: 0.5640
# Epoch 935/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9922 - Recall: 0.9908 - accuracy: 0.9916 - loss: 0.0021 - val_Precision: 0.5954 - val_Recall: 0.5830 - val_accuracy: 0.5887 - val_loss: 0.5604
# Epoch 936/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9931 - Recall: 0.9899 - accuracy: 0.9912 - loss: 0.0025 - val_Precision: 0.5958 - val_Recall: 0.5868 - val_accuracy: 0.5887 - val_loss: 0.5563
# Epoch 937/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9943 - Recall: 0.9927 - accuracy: 0.9935 - loss: 0.0015 - val_Precision: 0.5981 - val_Recall: 0.5868 - val_accuracy: 0.5906 - val_loss: 0.5593
# Epoch 938/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9941 - Recall: 0.9931 - accuracy: 0.9933 - loss: 0.0017 - val_Precision: 0.5969 - val_Recall: 0.5868 - val_accuracy: 0.5925 - val_loss: 0.5588
# Epoch 939/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9908 - Recall: 0.9889 - accuracy: 0.9899 - loss: 0.0023 - val_Precision: 0.5981 - val_Recall: 0.5868 - val_accuracy: 0.5906 - val_loss: 0.5624
# Epoch 940/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9935 - Recall: 0.9920 - accuracy: 0.9931 - loss: 0.0021 - val_Precision: 0.6004 - val_Recall: 0.5868 - val_accuracy: 0.5906 - val_loss: 0.5522
# Epoch 941/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9922 - Recall: 0.9908 - accuracy: 0.9918 - loss: 0.0016 - val_Precision: 0.5988 - val_Recall: 0.5887 - val_accuracy: 0.5962 - val_loss: 0.5581
# Epoch 942/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - Precision: 0.9931 - Recall: 0.9897 - accuracy: 0.9914 - loss: 0.0021 - val_Precision: 0.5988 - val_Recall: 0.5887 - val_accuracy: 0.5925 - val_loss: 0.5588
# Epoch 943/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9931 - Recall: 0.9914 - accuracy: 0.9924 - loss: 0.0020 - val_Precision: 0.5992 - val_Recall: 0.5868 - val_accuracy: 0.5906 - val_loss: 0.5577
# Epoch 944/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9935 - Recall: 0.9916 - accuracy: 0.9922 - loss: 0.0014 - val_Precision: 0.6000 - val_Recall: 0.5887 - val_accuracy: 0.5925 - val_loss: 0.5567
# Epoch 945/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9960 - Recall: 0.9939 - accuracy: 0.9950 - loss: 0.0014 - val_Precision: 0.6004 - val_Recall: 0.5868 - val_accuracy: 0.5906 - val_loss: 0.5590
# Epoch 946/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9950 - Recall: 0.9935 - accuracy: 0.9941 - loss: 0.0018 - val_Precision: 0.5988 - val_Recall: 0.5887 - val_accuracy: 0.5925 - val_loss: 0.5637
# Epoch 947/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9962 - Recall: 0.9956 - accuracy: 0.9960 - loss: 0.0010 - val_Precision: 0.6034 - val_Recall: 0.5943 - val_accuracy: 0.5962 - val_loss: 0.5561
# Epoch 948/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9947 - Recall: 0.9929 - accuracy: 0.9941 - loss: 0.0018 - val_Precision: 0.6019 - val_Recall: 0.5906 - val_accuracy: 0.5925 - val_loss: 0.5575
# Epoch 949/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9941 - Recall: 0.9929 - accuracy: 0.9931 - loss: 0.0018 - val_Precision: 0.6038 - val_Recall: 0.5925 - val_accuracy: 0.5962 - val_loss: 0.5609
# Epoch 950/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9933 - Recall: 0.9904 - accuracy: 0.9924 - loss: 0.0017 - val_Precision: 0.5977 - val_Recall: 0.5887 - val_accuracy: 0.5925 - val_loss: 0.5640
# Epoch 951/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9931 - Recall: 0.9904 - accuracy: 0.9918 - loss: 0.0024 - val_Precision: 0.5981 - val_Recall: 0.5868 - val_accuracy: 0.5925 - val_loss: 0.5614
# Epoch 952/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9952 - Recall: 0.9933 - accuracy: 0.9945 - loss: 0.0015 - val_Precision: 0.6031 - val_Recall: 0.5906 - val_accuracy: 0.5943 - val_loss: 0.5584
# Epoch 953/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9933 - Recall: 0.9920 - accuracy: 0.9922 - loss: 0.0020 - val_Precision: 0.6038 - val_Recall: 0.5925 - val_accuracy: 0.5962 - val_loss: 0.5561
# Epoch 954/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9931 - Recall: 0.9910 - accuracy: 0.9912 - loss: 0.0019 - val_Precision: 0.6004 - val_Recall: 0.5868 - val_accuracy: 0.5943 - val_loss: 0.5685
# Epoch 955/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9943 - Recall: 0.9924 - accuracy: 0.9937 - loss: 0.0020 - val_Precision: 0.5992 - val_Recall: 0.5868 - val_accuracy: 0.5925 - val_loss: 0.5671
# Epoch 956/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9947 - Recall: 0.9929 - accuracy: 0.9937 - loss: 0.0020 - val_Precision: 0.5988 - val_Recall: 0.5887 - val_accuracy: 0.5925 - val_loss: 0.5602
# Epoch 957/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9954 - Recall: 0.9935 - accuracy: 0.9948 - loss: 0.0016 - val_Precision: 0.6038 - val_Recall: 0.5925 - val_accuracy: 0.5962 - val_loss: 0.5590
# Epoch 958/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9931 - Recall: 0.9904 - accuracy: 0.9918 - loss: 0.0024 - val_Precision: 0.6034 - val_Recall: 0.5943 - val_accuracy: 0.5981 - val_loss: 0.5553
# Epoch 959/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9905 - Recall: 0.9887 - accuracy: 0.9895 - loss: 0.0029 - val_Precision: 0.6065 - val_Recall: 0.5962 - val_accuracy: 0.6000 - val_loss: 0.5525
# Epoch 960/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9929 - Recall: 0.9912 - accuracy: 0.9918 - loss: 0.0019 - val_Precision: 0.6019 - val_Recall: 0.5906 - val_accuracy: 0.5943 - val_loss: 0.5541
# Epoch 961/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9926 - Recall: 0.9914 - accuracy: 0.9920 - loss: 0.0021 - val_Precision: 0.5981 - val_Recall: 0.5868 - val_accuracy: 0.5906 - val_loss: 0.5625
# Epoch 962/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9928 - Recall: 0.9899 - accuracy: 0.9916 - loss: 0.0017 - val_Precision: 0.6042 - val_Recall: 0.5906 - val_accuracy: 0.5943 - val_loss: 0.5600
# Epoch 963/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9950 - Recall: 0.9931 - accuracy: 0.9939 - loss: 0.0013 - val_Precision: 0.5981 - val_Recall: 0.5868 - val_accuracy: 0.5906 - val_loss: 0.5632
# Epoch 964/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9943 - Recall: 0.9927 - accuracy: 0.9935 - loss: 0.0018 - val_Precision: 0.5992 - val_Recall: 0.5868 - val_accuracy: 0.5906 - val_loss: 0.5628
# Epoch 965/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9929 - Recall: 0.9916 - accuracy: 0.9916 - loss: 0.0019 - val_Precision: 0.5992 - val_Recall: 0.5868 - val_accuracy: 0.5906 - val_loss: 0.5673
# Epoch 966/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9941 - Recall: 0.9927 - accuracy: 0.9937 - loss: 0.0018 - val_Precision: 0.6019 - val_Recall: 0.5906 - val_accuracy: 0.5943 - val_loss: 0.5585
# Epoch 967/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9933 - Recall: 0.9918 - accuracy: 0.9924 - loss: 0.0024 - val_Precision: 0.6031 - val_Recall: 0.5906 - val_accuracy: 0.5943 - val_loss: 0.5585
# Epoch 968/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9939 - Recall: 0.9922 - accuracy: 0.9931 - loss: 0.0017 - val_Precision: 0.6019 - val_Recall: 0.5906 - val_accuracy: 0.5943 - val_loss: 0.5588
# Epoch 969/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9941 - Recall: 0.9920 - accuracy: 0.9933 - loss: 0.0018 - val_Precision: 0.6065 - val_Recall: 0.5962 - val_accuracy: 0.6000 - val_loss: 0.5557
# Epoch 970/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9931 - Recall: 0.9904 - accuracy: 0.9924 - loss: 0.0020 - val_Precision: 0.6038 - val_Recall: 0.5925 - val_accuracy: 0.5943 - val_loss: 0.5600
# Epoch 971/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9926 - Recall: 0.9910 - accuracy: 0.9916 - loss: 0.0019 - val_Precision: 0.6038 - val_Recall: 0.5925 - val_accuracy: 0.5962 - val_loss: 0.5619
# Epoch 972/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9931 - Recall: 0.9912 - accuracy: 0.9920 - loss: 0.0020 - val_Precision: 0.5981 - val_Recall: 0.5868 - val_accuracy: 0.5906 - val_loss: 0.5685
# Epoch 973/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9960 - Recall: 0.9943 - accuracy: 0.9954 - loss: 0.0015 - val_Precision: 0.5988 - val_Recall: 0.5887 - val_accuracy: 0.5925 - val_loss: 0.5665
# Epoch 974/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9943 - Recall: 0.9933 - accuracy: 0.9939 - loss: 0.0017 - val_Precision: 0.5988 - val_Recall: 0.5887 - val_accuracy: 0.5925 - val_loss: 0.5638
# Epoch 975/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9939 - Recall: 0.9924 - accuracy: 0.9935 - loss: 0.0021 - val_Precision: 0.5962 - val_Recall: 0.5849 - val_accuracy: 0.5906 - val_loss: 0.5633
# Epoch 976/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - Precision: 0.9943 - Recall: 0.9922 - accuracy: 0.9937 - loss: 0.0018 - val_Precision: 0.5962 - val_Recall: 0.5849 - val_accuracy: 0.5887 - val_loss: 0.5668
# Epoch 977/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9954 - Recall: 0.9941 - accuracy: 0.9945 - loss: 0.0017 - val_Precision: 0.5977 - val_Recall: 0.5887 - val_accuracy: 0.5925 - val_loss: 0.5687
# Epoch 978/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - Precision: 0.9924 - Recall: 0.9908 - accuracy: 0.9918 - loss: 0.0021 - val_Precision: 0.5981 - val_Recall: 0.5868 - val_accuracy: 0.5925 - val_loss: 0.5713
# Epoch 979/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9943 - Recall: 0.9927 - accuracy: 0.9935 - loss: 0.0016 - val_Precision: 0.5969 - val_Recall: 0.5868 - val_accuracy: 0.5925 - val_loss: 0.5668
# Epoch 980/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9945 - Recall: 0.9929 - accuracy: 0.9941 - loss: 0.0017 - val_Precision: 0.6000 - val_Recall: 0.5887 - val_accuracy: 0.5943 - val_loss: 0.5662
# Epoch 981/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9939 - Recall: 0.9920 - accuracy: 0.9931 - loss: 0.0014 - val_Precision: 0.6008 - val_Recall: 0.5906 - val_accuracy: 0.5925 - val_loss: 0.5632
# Epoch 982/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9943 - Recall: 0.9922 - accuracy: 0.9937 - loss: 0.0018 - val_Precision: 0.5969 - val_Recall: 0.5868 - val_accuracy: 0.5906 - val_loss: 0.5691
# Epoch 983/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9922 - Recall: 0.9908 - accuracy: 0.9918 - loss: 0.0022 - val_Precision: 0.6008 - val_Recall: 0.5906 - val_accuracy: 0.5925 - val_loss: 0.5615
# Epoch 984/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9947 - Recall: 0.9924 - accuracy: 0.9939 - loss: 0.0017 - val_Precision: 0.6008 - val_Recall: 0.5906 - val_accuracy: 0.5925 - val_loss: 0.5618
# Epoch 985/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9950 - Recall: 0.9933 - accuracy: 0.9941 - loss: 0.0015 - val_Precision: 0.6019 - val_Recall: 0.5906 - val_accuracy: 0.5943 - val_loss: 0.5677
# Epoch 986/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9952 - Recall: 0.9927 - accuracy: 0.9935 - loss: 0.0013 - val_Precision: 0.5981 - val_Recall: 0.5868 - val_accuracy: 0.5887 - val_loss: 0.5652
# Epoch 987/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9950 - Recall: 0.9933 - accuracy: 0.9935 - loss: 0.0014 - val_Precision: 0.5981 - val_Recall: 0.5868 - val_accuracy: 0.5887 - val_loss: 0.5708
# Epoch 988/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9941 - Recall: 0.9920 - accuracy: 0.9933 - loss: 0.0020 - val_Precision: 0.5981 - val_Recall: 0.5868 - val_accuracy: 0.5887 - val_loss: 0.5674
# Epoch 989/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9929 - Recall: 0.9912 - accuracy: 0.9922 - loss: 0.0027 - val_Precision: 0.5969 - val_Recall: 0.5868 - val_accuracy: 0.5887 - val_loss: 0.5636
# Epoch 990/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9952 - Recall: 0.9922 - accuracy: 0.9935 - loss: 0.0018 - val_Precision: 0.6038 - val_Recall: 0.5925 - val_accuracy: 0.5943 - val_loss: 0.5601
# Epoch 991/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9929 - Recall: 0.9912 - accuracy: 0.9920 - loss: 0.0017 - val_Precision: 0.6000 - val_Recall: 0.5887 - val_accuracy: 0.5906 - val_loss: 0.5710
# Epoch 992/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9956 - Recall: 0.9948 - accuracy: 0.9952 - loss: 0.0014 - val_Precision: 0.6000 - val_Recall: 0.5887 - val_accuracy: 0.5906 - val_loss: 0.5690
# Epoch 993/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9943 - Recall: 0.9924 - accuracy: 0.9933 - loss: 0.0018 - val_Precision: 0.5992 - val_Recall: 0.5868 - val_accuracy: 0.5887 - val_loss: 0.5692
# Epoch 994/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9935 - Recall: 0.9922 - accuracy: 0.9931 - loss: 0.0020 - val_Precision: 0.6008 - val_Recall: 0.5906 - val_accuracy: 0.5925 - val_loss: 0.5687
# Epoch 995/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9950 - Recall: 0.9937 - accuracy: 0.9941 - loss: 0.0015 - val_Precision: 0.6027 - val_Recall: 0.5925 - val_accuracy: 0.5943 - val_loss: 0.5703
# Epoch 996/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9937 - Recall: 0.9914 - accuracy: 0.9920 - loss: 0.0020 - val_Precision: 0.6019 - val_Recall: 0.5906 - val_accuracy: 0.5925 - val_loss: 0.5649
# Epoch 997/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9950 - Recall: 0.9935 - accuracy: 0.9939 - loss: 0.0015 - val_Precision: 0.5958 - val_Recall: 0.5868 - val_accuracy: 0.5887 - val_loss: 0.5717
# Epoch 998/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9958 - Recall: 0.9945 - accuracy: 0.9952 - loss: 9.8809e-04 - val_Precision: 0.6004 - val_Recall: 0.5868 - val_accuracy: 0.5925 - val_loss: 0.5740
# Epoch 999/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9939 - Recall: 0.9922 - accuracy: 0.9927 - loss: 0.0021 - val_Precision: 0.6008 - val_Recall: 0.5906 - val_accuracy: 0.5943 - val_loss: 0.5694
# Epoch 1000/1000
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - Precision: 0.9937 - Recall: 0.9920 - accuracy: 0.9931 - loss: 0.0019 - val_Precision: 0.6038 - val_Recall: 0.5925 - val_accuracy: 0.5943 - val_loss: 0.5627
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - Precision: 0.6038 - Recall: 0.5925 - accuracy: 0.5943 - loss: 0.5627
# Test Loss: 0.5627, Test Accuracy: 0.5943 Precision: 0.6038 Recall: 0.5925

# %%
# Plot confusion matrix for test set predictions
# Use the non-categorical classes for the labels in the confusion matrix.
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
cm = confusion_matrix(np.argmax(y_test, axis=1), y_pred_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(processed_complaints_df['Department'].dropna()))
disp.plot(cmap=plt.cm.Blues)
# Make the pips of the x-axis 60 degrees to make them easier to read
plt.xticks(rotation=60)
plt.title('Confusion Matrix for Test Set Predictions')
plt.show()
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
# Plot training and validation loss, accuracy, precision, and recall curves
history = model.history.history
plt.figure(figsize=(12, 10))
plt.subplot(2, 2, 1)
plt.plot(history['loss'], label='Training Loss')
plt.plot(history['val_loss'], label='Validation Loss')
plt.title('Loss Curves')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.subplot(2, 2, 2)
plt.plot(history['accuracy'], label='Training Accuracy')
plt.plot(history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Curves')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.subplot(2, 2, 3)
plt.plot(history['Precision'], label='Training Precision')
plt.plot(history['val_Precision'], label='Validation Precision')
plt.title('Precision Curves')
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.legend()
plt.subplot(2, 2, 4)
plt.plot(history['Recall'], label='Training Recall')
plt.plot(history['val_Recall'], label='Validation Recall')
plt.title('Recall Curves')
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Check the model's predictions on the validation set with missing department values
y_val_pred = model.predict(X_val)
y_val_pred_classes = np.argmax(y_val_pred, axis=1)
print("Predicted Departments for Validation Set:")
print(y_val_pred_classes)

# Print out a few of the original complaints with missing department values alongside their predicted department to see if the predictions make sense
for i in range(5):
    print(f"Original Complaint: {complaints_df.loc[null_dept_indices[i], 'Complaint Description']}")
    print(f"Predicted Department: {np.unique(processed_complaints_df['Department'].dropna())[y_val_pred_classes[i]]}")
    print("-" * 50)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Predicted Departments for Validation Set:
# [0 2 0 2 5 4 2 2 2 0 3 2 1 5 0 2 0 0 0 0 0 1 2 3 2 2 1 0 2 0 0 0 0 0 2 0 0
#  0 2 0 2 3 2 1 2 2 2 2 4 0 0 2 2 2 2 0 2 0 2 2 3 0 2 2 0 2 4 1 2 4 2 4 0 2
#  0 2 0 0 2 4 6 2 0 2 3 2 0 2 2 2 3 0 1 0 1 0 0 4 1 0 0 0 0 0 1 2 0 2 0 0 3
#  2 1 2 2 1 0 0 1 0 2 0 3 1 0 2 0 0 0 0 0 0 0 0 2 0 0 0 2 3 2 0 0 0 0 1 3 1
#  2 2 0 0 0 2 1 2 2 1 3 1 2 0 1 5 3 2 4 1 1 2 1 1 2 1 0 2 1 1 4 2 3 5 3 1 1
#  2 1 2 3 1 2 2 1 1 1 2 1 2 1 2 1 6 3 1 1 2 1 1 2 4 1 1 4 1 0 1 1 2 5 5 3 3
#  0 1 0 1 2 2 4 4 2 3 3 1 2 3 6 1 3 0 3 3 3 1 1 2 3 0 0 1 4 1 2 2 2 2 2 2 2
#  0 1 0 2 2 1 4 2 2 1 2 3 3 4 2 3 2 3 1 3 2 0 1 1 2 1 2 3 5 2 0 1 3 2 3 2 1
#  2 3 2 2 1 2 0 1 1 2 1 3 1 5 1 2 1 3 2 0 2 1 0 1 2 2 0 1 0 2 2 1 2 1 1 2 2
#  0 5 4 3 1 2 2 3 5 5 2 1 1 1 0 2 5 1 1 1 0 3 0 1 2 1 2 3 3 2 2 2 2 1 1 2 6
#  0 0 0 0 0 2 1 0 2 1 1 5 1 0]
# Original Complaint: On XX/XX/XX22 I found out that my account was frozen for no apparent reason. I went to the BOA branch in XXXX XXXX NY, I explained whats going on and he made the call he beleived me after that call. I'm on a fixed income and BOA is holding my funds hostage for no reason. I had XXXX XXXXXXXX and I'm on a fixed income and I have XXXX children and can not afford the high corporation bank as BOA to keep getting away with this.
# Predicted Department: CASA
# --------------------------------------------------
# Original Complaint: Got 5 hard inquiries I dont recognize, from XXXX XXXX XXXX on XX/XX/XXXX, 3 from BK of ABC on XX/XX/XXXX, XX/XX/XXXX, and XX/XX/XXXX And XXXX XXXX on XX/XX/XXXXXXXX XXXX
# Predicted Department: Credit Reports
# --------------------------------------------------
# Original Complaint: BoA makes it VERY difficult to make a reg E claim. Criminal!! Im a bank expert and know it shouldnt be this hard.
# They sent me an email, likely fraudulent transaction. It was. So go to mobile banking, low tran business acct. Clearly fraud.
# Tried to dispute via mobile.
# Had to go to internet banking.
# Enter last 6 DC - done Enter TIN - done Then 6 digit code via text - done Then new passcode - done And repeat. And repeat. Stuck in a loop.
# Had to call. Extended hold time. Turns out internet banking uses debit card and since debit card has a hold, you can not dispute on internet banking.
# Frustratingly on hold, message keeps saying you could dispute on mobile or internet banking. Infuriating.
# After 32 minutes hold- spend XX minutes on a call to dispute an obviously fraudulent set of transactions ; a process that should be done via text or in mobile banking in a minute.
# Seems to me that BofA makes it confusing and difficult on purpose.
# Predicted Department: CASA
# --------------------------------------------------
# Original Complaint: We have been with Bank of ABC mortgage for XX or more years and have never been late with a house payment.In XXXX of XXXX my husband passed away and I lost all income except Social Security.In XXXX of XXXX i applied for a modification loan with Bank of ABC.They had me make three trial payments of {$650.00} on XXXX, XXXX and XXXX which was {$100.00} less than the normal payment and told me several times and even had it in the paper work that I could not make anything but that amount.I called them several times to ask about the payments that I was still receiving with the old amount and they assured me that it would all fall into place after the three months were up.After the new loan amount went thru they put 3 late payments on my credit report for XXXX, XXXX and XXXX which has affected my credit report very much.I have disputed it thru XXXX and XXXX with no results and was told by a manger with Bank of ABC that they were not changing it.Of course this is effecting me trying to find cheaper insurance or anything else.I really need some help with this.
# Predicted Department: Credit Reports
# --------------------------------------------------
# Original Complaint: I reached out to Bank of ABC on XX/XX/XXXX at XXXX XXXX  and spoke to a representative from Arkansas, I told him that I opened an account back in XX/XX/XXXX and the reason for opening an account was because it was advertised that there would be a {$XX0.00} credit on my account, if I were to spend {$1000.00} within 90 days ( according to the fine print ). I realized I never received it, after looking into my account and I spent that amount way before the 90 days, but it was not credited to my account.
# The representative mentioned to me that he couldn't apply that promotion because it was too late. I told him that promotion should be honored and that it was not my fault that it was not credited to my account. I asked to speak with a manager and his manager ( XXXX ) would not speak with me and would tell the representative what to say to avoid talking to me. I asked to speak with the manager twice and the representative made excuses for him. VERY UNPROFESSIONAL!! If this is not honored to my account. I will be escalating this matter to court. This is False advertisement and very misleading and Now I'm wondering how many people this has happened too??
# Predicted Department: Others
# --------------------------------------------------

# %%
# Create the sentiment analyzer and add it as a new column in a new dataframe to avoid messing with the original
anal_sent = SentimentIntensityAnalyzer()
sentiment_complaints_df = processed_complaints_df.copy()

sentiment_complaints_df['Sentiment Score'] = sentiment_complaints_df['Complaint Description'].apply(lambda x: anal_sent.polarity_scores(x)['compound'])
print(sentiment_complaints_df[['Complaint Description', 'Sentiment Score']].head())
# Out:
#                                Complaint Description  Sentiment Score
# 0  xxxxxx<NUM><NUM> opened safe balance account o...          -0.8720
# 1  item bank abc credit report belong must remove...           0.4588
# 2  xxxxxx<NUM><NUM> found account frozen apparent...           0.0000
# 3  so last time phone b prepaid regarding edd acc...           0.7096
# 4  got <NUM> hard inquiry dont recognize xxxx xxx...          -0.1027

# %%
# Do sentiment analysis on the orignal complaints w/o preprocessing and compare the scores to the preprocessed ones to see if there is a significant difference
original_sentiment_complaints_df = dept_filled_complaints_df.reset_index().copy()
original_sentiment_complaints_df['Sentiment Score'] = original_sentiment_complaints_df['Complaint Description'].apply(lambda x: anal_sent.polarity_scores(x)['compound'])
print(original_sentiment_complaints_df[['Complaint Description', 'Sentiment Score']].head())
# Out:
#                                Complaint Description  Sentiment Score
# 0  on XX/XX/XX22 I opened a safe balance account ...          -0.9488
# 1  There is an item from Bank of ABC on my credit...          -0.1207
# 2  On XX/XX/XX22 I found out that my account was ...          -0.5267
# 3  So, last time I was on the phone with b of a p...           0.1901
# 4  Got 5 hard inquiries I dont recognize, from XX...          -0.1027

# %%
# print the full text of each complaint in the head() of the original and preprocessed sentiment dataframes to
# compare the changes made by preprocessing and see if there is a significant difference in the sentiment scores.
# Skip entries missing an index
for i in range(10):
    if i not in original_sentiment_complaints_df.index or i not in sentiment_complaints_df.index:
        continue
    print(f"Original Complaint: {original_sentiment_complaints_df.loc[i]['Complaint Description']}")
    print(f"Original Sentiment Score: {original_sentiment_complaints_df.loc[i]['Sentiment Score']}")
    print(f"Preprocessed Complaint: {sentiment_complaints_df.loc[i]['Complaint Description']}")
    print(f"Preprocessed Sentiment Score: {sentiment_complaints_df.loc[i]['Sentiment Score']}")
    print("-" * 50)
# Out:
# Original Complaint: on XX/XX/XX22 I opened a safe balance account online using my payroll check of over {$600.00} as my account opener. On XX/XX/XX22, I attempted to login to my app and received a " account locked contact customer service @ XXXX '' error message. I placed the call and was told I would have to go to a branch to verify my identity, which I did. At the same time, I was told I had a positive balance of of {$650.00} and could make a withdrawal from the teller, which I did for {$400.00} leaving a balance of + {$250.00}. Shortly after that, I deposited a mobile check for {$5XX.00}. On XX/XX/XX22, again I attempted to login and received the previous error message along with 3 emails stating a hold was placed on my account. Contacting the same previous number I was told that my acct was being closed by the Risk Dept. due to lack of identity verification, which I told them I had done the day before. I was then told it didn't matter the account was already being closed and it was not reversible, so I asked about my balance and was then told I was overdrawn by {$400.00} and I would have to pay that before I could be set up with a new acct. None of this makes logically sense, nor does it in anyway seem legal. I have contacted my attorney who suggested that I attempt to resolve the issue with a supervisor or manager before he makes any court filings so that is what I am doing now. All of this has not just caused me unnecessary stress but put myself and my family into serious financial hardship and suffering. We were force to miss XXXX with family due to lack of funds to travel, I have no way to pay for the propane that is for cooking and heating my home, my mortgage payment, car registration and insurance are now all past due resulting in late fees totalling {$350.00}, all caused by poorly trained bank employees!
# Original Sentiment Score: -0.9488
# Preprocessed Complaint: xxxxxx<NUM><NUM> opened safe balance account online using payroll check <NUM><NUM><NUM><NUM><NUM> account opener xxxxxx<NUM><NUM> attempted login app received account locked contact customer service xxxx error message placed call told would go branch verify identity did time told positive balance <NUM><NUM><NUM><NUM><NUM> could make withdrawal teller <NUM><NUM><NUM><NUM><NUM> leaving balance <NUM><NUM><NUM><NUM><NUM> shortly that deposited mobile check <NUM>xx<NUM><NUM> xxxxxx<NUM><NUM> attempted login received previous error message along <NUM> email stating hold placed account contacting previous number told acct closed risk dept due lack identity verification told done day before told matter account already closed reversible asked balance told overdrawn <NUM><NUM><NUM><NUM><NUM> would pay could set new acct none make logically sense anyway seem legal contacted attorney suggested attempt resolve issue supervisor manager make court filing now caused unnecessary stress put family serious financial hardship suffering force miss xxxx family due lack fund travel way pay propane cooking heating home mortgage payment car registration insurance past due resulting late fee totalling <NUM><NUM><NUM><NUM><NUM> caused poorly trained bank employee
# Preprocessed Sentiment Score: -0.872
# --------------------------------------------------
# Original Complaint: There is an item from Bank of ABC on my credit report that does not belong to me and must be removed because its a fraud item but they always return back confirming that this account belongs to me with no proof. I need this item removed from my credit report because its effecting my life and i will look into legal means if this does not get solved soon
# Original Sentiment Score: -0.1207
# Preprocessed Complaint: item bank abc credit report belong must removed fraud item always return back confirming account belongs proof need item removed credit report effecting life look legal mean get solved soon
# Preprocessed Sentiment Score: 0.4588
# --------------------------------------------------
# Original Complaint: On XX/XX/XX22 I found out that my account was frozen for no apparent reason. I went to the BOA branch in XXXX XXXX NY, I explained whats going on and he made the call he beleived me after that call. I'm on a fixed income and BOA is holding my funds hostage for no reason. I had XXXX XXXXXXXX and I'm on a fixed income and I have XXXX children and can not afford the high corporation bank as BOA to keep getting away with this.
# Original Sentiment Score: -0.5267
# Preprocessed Complaint: xxxxxx<NUM><NUM> found account frozen apparent reason went boa branch xxxx xxxx ny explained whats going made call beleived call fixed income boa holding fund hostage reason xxxx xxxxxxxx fixed income xxxx child afford high corporation bank boa keep getting away this
# Preprocessed Sentiment Score: 0.0
# --------------------------------------------------
# Original Complaint: So, last time I was on the phone with b of a prepaid regarding my edd account, I was told that actually, multiple cards remained active at the time of my most current card being active. So I believe I have a right to file a claim on my entire account since they dont even know which cards are active at what time. But they refuse to let me file a claim.
# Original Sentiment Score: 0.1901
# Preprocessed Complaint: so last time phone b prepaid regarding edd account told actually multiple card remained active time current card active believe right file claim entire account since dont even know card active time refuse let file claim
# Preprocessed Sentiment Score: 0.7096
# --------------------------------------------------
# Original Complaint: Got 5 hard inquiries I dont recognize, from XXXX XXXX XXXX on XX/XX/XXXX, 3 from BK of ABC on XX/XX/XXXX, XX/XX/XXXX, and XX/XX/XXXX And XXXX XXXX on XX/XX/XXXXXXXX XXXX
# Original Sentiment Score: -0.1027
# Preprocessed Complaint: got <NUM> hard inquiry dont recognize xxxx xxxx xxxx xxxxxxxx <NUM> bk abc xxxxxxxx xxxxxxxx xxxxxxxx xxxx xxxx xxxxxxxxxxxx xxxx
# Preprocessed Sentiment Score: -0.1027
# --------------------------------------------------
# Original Complaint: In XXXX of XX22, I discovered that a former tenant had stolen my identity. I found this during the eviction process & after reviewing my entire credit report. There were several Bank of ABC accounts opened up in my name. I immediately notified the Bank of ABC fraud unit and also provided them with my Police report, FTC report, Drivers license, and a utility bill. Bank of ABC continues to affirm the accounts stating that payments were made on the account ( s ) from a checking account in my name. Ive tried to object to their decision because there were three fraudulent checking accounts also opened by the fraudsters. I do not know what more I can do aside from filing a lawsuit against the company.
# Original Sentiment Score: -0.9423
# Preprocessed Complaint: xxxx xx<NUM><NUM> discovered former tenant stolen identity found eviction process reviewing entire credit report several bank abc account opened name immediately notified bank abc fraud unit also provided police report ftc report driver license utility bill bank abc continues affirm account stating payment made account checking account name ive tried object decision three fraudulent checking account also opened fraudsters know aside filing lawsuit company
# Preprocessed Sentiment Score: -0.9423
# --------------------------------------------------
# Original Complaint: I, the consumer am aware and have proof that BANK OF ABC has and continues to violate my consumer rights. I have observed at least 9 violations pursuant XX USC XX93f. BANK OF ABC received a Cease and Desist in reference to this matter XX/XX/XX22. They have failed to provide results of the investigation and its findings used to determine actions of withholding the consumers funds in a reported electronic transfer error since XX/XX/XX22 ; notice of the right to request reproductions ; mail to the consumer reproductions of all documents which the financial institution relied on to conclude that such error did not occur ; or returning the funds as directed by the consumer. BOA has and continues to violate consumer pursuant to XX USC XX93 f. As a result to their gross, negligent and willful behavior, I have been injured numerous times.
# Original Sentiment Score: -0.9725
# Preprocessed Complaint: i consumer aware proof bank abc continues violate consumer right observed least <NUM> violation pursuant xx usc xx<NUM><NUM>f bank abc received cease desist reference matter xxxxxx<NUM><NUM> failed provide result investigation finding used determine action withholding consumer fund reported electronic transfer error since xxxxxx<NUM><NUM> notice right request reproduction mail consumer reproduction document financial institution relied conclude error occur returning fund directed consumer boa continues violate consumer pursuant xx usc xx<NUM><NUM> f result gross negligent willful behavior injured numerous time
# Preprocessed Sentiment Score: -0.9719
# --------------------------------------------------
# Original Complaint: I have filed a dispute in regards to an inaccurate Account on my consumer report. It has been well over 60 days and I haven't received any investigation results.
# Original Sentiment Score: -0.1531
# Preprocessed Complaint: filed dispute regard inaccurate account consumer report well <NUM><NUM> day received investigation result
# Preprocessed Sentiment Score: -0.1531
# --------------------------------------------------
# Original Complaint: RE : Purchase of Goods on XXXX ( from XXXX ) using Bank of ABC XXXX Card, and Non-Receipt of Goods-BOA wont file Dispute and Give me Credit This complaint is against Bank of ABC XXXX XXXX Card, for refusing to file a Dispute, on my behalf, for merchandise not delivered by a company called XXXX.
# Screen prints from my BOA account are attached, showing the charge of XX/XX/XXXX.
# Screen prints show there is no record in my Messages tab, that a Dispute had been filed. I called at least twice, and spoke to BOA agents, asking that a Dispute be filed. Yet when I try and click on the transaction myself, to file a Dispute, online to correct the problem, I am prevented from filing the Dispute, as I am told I would be filing a Duplicate Dispute.
#
# BACKGROUND TO COMPLAINT XXXX XXXX, I purchased 2 belts from a Pinterest Ad that popped up, and I used my master card to pay for them. Nothing was mentioned on the order blank, that these items came from XXXX ( which would cause a delay in delivery ), nor was there any mention of the items not being in stock.
# When I received confirmation of the order, it was noted that there would be a delay in delivery, from XXXX XXXX business days ). The confirmation email also had a tracking number. The tracking number was for some group apparently out of XXXX, and when I clicked on the tracking number, it did not give specifics, but appeared to be tracking something coming from some where..
#
# I Contacted Seller by email XX/XX/XXXX, XXXX pm, received email from XXXX, for XXXX # XXXX, confirming order. Ant chged to my XXXX was {$32.00} USD I clicked on View your Order and was given the Shipper and Tracking number : Shipper : XXXX ; Tracking number : XXXX. When I clicked on the tracking number, it had not been sent yet. I looked up this XXXX  through XXXX, and found XXXX, XXXX XXXX XXXX XXXX, XXXX XXXX, CA XXXX. ( This address, according to USPS records and XXXX, is just a house/residence, in XXXX XXXX XXXX California ) ).
# This address is a rental propertyin XXXX XXXX???
#
# It is interesting that on the confirmed order page sent me, it specifies the amount I paid, followed by USD when in fact the company has an office stateside in the United States. If they are a US firm, they shouldnt need to specdify the amount I paid was in US dollars, rtight?
#
# XX/XX/XXXX, XXXX XXXX, I received an email from XXXX, indicating my order is on the way. The first link is Track order with XXXX which is useless as it takes you to an APP page where yyou can get the XXXX  app downloaded. Since I did not want a XXXX app on my XXXX I did not dowm load that app.
#
# When I clicked the tracking link, It has the same company and tracking number. It also stated : You will get shipping and delivery updates by email and text. I have not received ANY emails or texts with order updates. Ihave had to go to past emails from XXXX, and click on the tracking number, to find out status.
# XXXX XXXX XXXX  I emailed the seller through their website, asking when it would arrive.
# XX/XX/XXXX at XXXX XXXX. Seller responded, to my email address, and I WAS THEN told, all orders take from XXXX to XXXX business days to arrive at destination. I was also given a link to the tracking number again.
# By the way, that is a way to escalate your stock sales, on the stock exchanges, at year end, by claiming sales are through the roof, when in fact you have no product to sell or ship, right?????
# XX/XX/XXXX, XXXX XXXX, I contacted seller again, complaining that the item now does not even show as TRACKABLE. I wanted to reverse my credit card charges.
#
# XX/XX/XXXX, XXXXXXXX XXXX, I get a return email, Telling me again, all orders take from XXXX XXXX business deays to arrive. Seller did not address my concerns that now, the link does not show the item going anywhere, link does not indicate city it is in, city it is going to, or when it is expected arrival date is. Iwas told it was already in transit, and should be arriving in that time frame.
# XXXX XXXX XXXX if the item exists, and has been sent, the item apparently is stuck somewhere, or perhaps not even sent. I have not received the item. Bank of ABC has NOT filed a Dispute for me, as I asked, AND I am prevented from filing a dispute myself online, because it tells me it is a Duplicate Dispute.
# When contacted by email, the seller will not answer any direct questions, like, in what city is it now, what date should I be expecting it.
# On XX/XX/XXXX, on finding out delivery date was so far out. I asked to cancel the item by email. My request to cancel the order was ignored, and instead I was sent another email, and told I could track it by clicking on the link in the email.
#
# When I realized the seller had no intention of cancelling the order as I had requested, in my email, I contacted Bank of ABC XXXX XXXX, art their XXXX number. I explained the above, and asked that they file a dispute for the item, which was now on my credit card statement online.
# The fellow at the BOA XXXX XXXX number sounded like he was taking down all the relevant information I gave him. And said he filed a Dispute for me.
#
# Shortly thereafter, I received an email. I went online in my BOA XXXX account, to see the messages center referred to, in the email. By the sounds of the email, it sounded like the BOA agent HAD NOT filed the Dispute against XXXX but expected me to do that, by going into my account. In my messages account online there was NO email or communication whatsoever, on the Dispute I thought he had filed forme, Against the XXXX charge.
# On DATE, I called BOA, spoke to, and asked the status of the Dispute. I was told it could take XXXX to XXXX hours fore that to show up. And that I would receive notification BOTH in writing, by USPS XXXX, and by a Message in my account.
# On XX/XX/XXXX,, I contacted Bank of ABC again, and gave all details regarding this transaction to file a dispute : The tracking number XXXX, transaction date XX/XX/XXXX, Reference Number XXXX, told them it had been ordered XX days ago ( {$32.00} ) and the item was charged to my account on that date yet I had not received any merchandise, and little satisfaction emailing them. I was told that they put the Dispute in then.
#
# XX/XX/XXXX, at XXXX am, I called BOA again, and spoke to a person who called herself XXXX and explained that I had on the phone filed a Dispute, XX/XX/XXXX, yet had received no confirmation, etc that it was filed. XXXX said it was XXXX # XXXX XXXX XXXX. That is great -- - but that CHARGE is still on my BOA statement, and it appears I will have to pay for it in XXXX, unless BOA puts it in pending status. Further, I STILL have nothing in writing about the Dispute being officially filed, the case, or a credit, or anything. This speaks to poor procedure following on Bank of ABCs part. When people call in to file the Dispute, it should be recorded in their account, visibly, so the card holder can see what is going on.
# At this point, Sunday, XX/XX/XXXX, there is STILL NO notification of a Dipute filed against this Crovable who sold me the belts, immediately charged it to my credit card, yet has not yet delivered, Furthermore, there is no USPS letter, from BOA XXXXXXXX XXXX that I have received, stating the XXXX  issue is even in process. Nor is there any message on a XXXX Dispute in my Bank of ABC Online Message Center.
# Thus, since I have noo proof in writing that a Dispute has been filed against XXXX, as far as I am concerned, BOA never filed the Dispute.
# Original Sentiment Score: 0.9794
# Preprocessed Complaint: purchase good xxxx xxxx using bank abc xxxx card nonreceipt goodsboa wont file dispute give credit complaint bank abc xxxx xxxx card refusing file dispute behalf merchandise delivered company called xxxx screen print boa account attached showing charge xxxxxxxx screen print show record message tab dispute filed called least twice spoke boa agent asking dispute filed yet try click transaction myself file dispute online correct problem prevented filing dispute told would filing duplicate dispute background complaint xxxx xxxx purchased <NUM> belt pinterest ad popped up used master card pay them nothing mentioned order blank item came xxxx would cause delay delivery mention item stock received confirmation order noted would delay delivery xxxx xxxx business day confirmation email also tracking number tracking number group apparently xxxx clicked tracking number give specific appeared tracking something coming where contacted seller email xxxxxxxx xxxx pm received email xxxx xxxx xxxx confirming order ant chged xxxx <NUM><NUM><NUM><NUM> usd clicked view order given shipper tracking number shipper xxxx tracking number xxxx clicked tracking number sent yet looked xxxx xxxx found xxxx xxxx xxxx xxxx xxxx xxxx xxxx ca xxxx address according usps record xxxx houseresidence xxxx xxxx xxxx california address rental propertyin xxxx xxxx interesting confirmed order page sent me specifies amount paid followed usd fact company office stateside united state u firm shouldnt need specdify amount paid u dollar rtight xxxxxxxx xxxx xxxx received email xxxx indicating order way first link track order xxxx useless take app page yyou get xxxx app downloaded since want xxxx app xxxx dowm load app clicked tracking link company tracking number also stated get shipping delivery update email text received email text order update ihave go past email xxxx click tracking number find status xxxx xxxx xxxx emailed seller website asking would arrive xxxxxxxx xxxx xxxx seller responded email address told order take xxxx xxxx business day arrive destination also given link tracking number again way way escalate stock sale stock exchange year end claiming sale roof fact product sell ship right xxxxxxxx xxxx xxxx contacted seller again complaining item even show trackable wanted reverse credit card charge xxxxxxxx xxxxxxxx xxxx get return email telling again order take xxxx xxxx business deays arrive seller address concern now link show item going anywhere link indicate city in city going to expected arrival date is iwas told already transit arriving time frame xxxx xxxx xxxx item exists sent item apparently stuck somewhere perhaps even sent received item bank abc filed dispute me asked prevented filing dispute online tell duplicate dispute contacted email seller answer direct question like city now date expecting it xxxxxxxx finding delivery date far out asked cancel item email request cancel order ignored instead sent another email told could track clicking link email realized seller intention cancelling order requested email contacted bank abc xxxx xxxx art xxxx number explained above asked file dispute item credit card statement online fellow boa xxxx xxxx number sounded like taking relevant information gave him said filed dispute me shortly thereafter received email went online boa xxxx account see message center referred to email sound email sounded like boa agent filed dispute xxxx expected that going account message account online email communication whatsoever dispute thought filed forme xxxx charge date called boa spoke to asked status dispute told could take xxxx xxxx hour fore show up would receive notification writing usps xxxx message account xxxxxxxx contacted bank abc again gave detail regarding transaction file dispute tracking number xxxx transaction date xxxxxxxx reference number xxxx told ordered xx day ago <NUM><NUM><NUM><NUM> item charged account date yet received merchandise little satisfaction emailing them told put  ...
# Preprocessed Sentiment Score: 0.994
# --------------------------------------------------
# Original Complaint: BoA makes it VERY difficult to make a reg E claim. Criminal!! Im a bank expert and know it shouldnt be this hard.
# They sent me an email, likely fraudulent transaction. It was. So go to mobile banking, low tran business acct. Clearly fraud.
# Tried to dispute via mobile.
# Had to go to internet banking.
# Enter last 6 DC - done Enter TIN - done Then 6 digit code via text - done Then new passcode - done And repeat. And repeat. Stuck in a loop.
# Had to call. Extended hold time. Turns out internet banking uses debit card and since debit card has a hold, you can not dispute on internet banking.
# Frustratingly on hold, message keeps saying you could dispute on mobile or internet banking. Infuriating.
# After 32 minutes hold- spend XX minutes on a call to dispute an obviously fraudulent set of transactions ; a process that should be done via text or in mobile banking in a minute.
# Seems to me that BofA makes it confusing and difficult on purpose.
# Original Sentiment Score: -0.9907
# Preprocessed Complaint: boa make difficult make reg e claim criminal im bank expert know shouldnt hard sent email likely fraudulent transaction wa go mobile banking low tran business acct clearly fraud tried dispute via mobile go internet banking enter last <NUM> dc done enter tin done <NUM> digit code via text done new passcode done repeat repeat stuck loop call extended hold time turn internet banking us debit card since debit card hold dispute internet banking frustratingly hold message keep saying could dispute mobile internet banking infuriating <NUM><NUM> minute hold spend xx minute call dispute obviously fraudulent set transaction process done via text mobile banking minute seems bofa make confusing difficult purpose
# Preprocessed Sentiment Score: -0.988
# --------------------------------------------------
